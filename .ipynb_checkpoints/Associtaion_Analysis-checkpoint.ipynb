# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules
import pandas as pd
from konlpy.tag import Okt
import os
from collections import Counter

path = os.getcwd()

# pd.set_option('display.max_columns',8)
kor_df = pd.read_excel(path + "/data/clean_kor.xlsx", engine='openpyxl')

# %%
tagger = Okt()
kor_nouns = kor_df['kor_nouns'].apply(lambda x: tagger.nouns(x))
transactions = kor_nouns.tolist()
transactions
# Out:
# [['속눈썹'],
#  ['입술', '색', '발라'],
#  ['노력', '코로나', '사망자', '영안', '눈물', '의료', '의료', '코로나', '코로나', '사망자'],
#  ['스토리', '살짝', '피드', '올릴랭', '티엠', '말', '하자', '화표', '코로나'],
#  ['리스',
#   '남친',
#   '코디',
#   '미니',
#   '미니',
#   '코로나',
#   '얼룩',
#   '캐',
#   '주얼',
#   '캐',
#   '주얼',
#   '코디',
#   '스탠다드',
#   '학원',
#   '리스',
#   '리스',
#   '코드',
#   '라피',
#   '나이키',
#   '볼텍스'],
#  ['스타', '스타', '천안', '코로나', '코로나'],
#  ['이유', '뭐'],
#  [],
#  ['커피', '심장', '세근'],
#  ['눈앞',
#   '성적',
#   '앞',
#   '성장',
#   '은',
#   '써밋',
#   '대교',
#   '써밋',
#   '써밋',
#   '눈높이',
#   '장판',
#   '장판',
#   '덕분',
#   '코로나',
#   '학력',
#   '격차',
#   '실행',
#   '원조',
#   '학습',
#   '써밋'],
#  ['알',
#   '근르가즘',
#   '스타',
#   '운동',
#   '스타',
#   '헬',
#   '스타',
#   '헬스',
#   '스포',
#   '애니',
#   '헬스장',
#   '금요일',
#   '운동',
#   '코로나',
#   '헬린',
#   '벌',
#   '업',
#   '현실',
#   '돼지'],
#  ['휘트니', '스', '기점', '코로나', '예방', '매일', '방역', '소독', '안심', '운동'],
#  ['방역',
#   '칙',
#   '인',
#   '집합',
#   '금지',
#   '인',
#   '상모',
#   '임금',
#   '헌팅',
#   '포차',
#   '류',
#   '술집',
#   '서서',
#   '아침',
#   '술',
#   '헌팅',
#   '이야기',
#   '예끼',
#   '요',
#   '털',
#   '사면',
#   '바리',
#   '벌레',
#   '라며',
#   '일찍',
#   '줏어',
#   '새',
#   '새끼',
#   '열정',
#   '기름',
#   '부어',
#   '초가삼간',
#   '녀석',
#   '모이',
#   '모이',
#   '경남',
#   '전국',
#   '단위',
#   '숫자',
#   '욕',
#   '코로나',
#   '뭐',
#   '이지마',
#   '끝',
#   '안나',
#   '단계',
#   '리자',
#   '나중',
#   '모이',
#   '나중',
#   '놀수'],
#  ['스탠다드',
#   '선물',
#   '상의',
#   '스웨',
#   '트',
#   '투맨',
#   '하의',
#   '스웨',
#   '트',
#   '팬츠',
#   '신발',
#   '플러피룸',
#   '슈즈',
#   '옷',
#   '느낌',
#   '옷',
#   '가지',
#   '스탠다드',
#   '브랜드',
#   '달리',
#   '질감',
#   '소재',
#   '구성',
#   '브랜드',
#   '옷',
#   '가성',
#   '상의',
#   '소재',
#   '보리',
#   '짱짱',
#   '함',
#   '택배',
#   '마음',
#   '쫀쫀',
#   '매우',
#   '바지',
#   '사이즈',
#   '평소',
#   '허벅지',
#   '부분',
#   '만족',
#   '허리',
#   '스트링',
#   '커서',
#   '한번',
#   '밑단',
#   '보리',
#   '조거',
#   '형식',
#   '수족',
#   '냉증',
#   '발',
#   '워',
#   '겨울',
#   '양말',
#   '신발',
#   '폭',
#   '폭',
#   '신하',
#   '맨',
#   '맨',
#   '거려',
#   '아주',
#   '만족',
#   '무탠',
#   '다드',
#   '서프라이즈',
#   '스탠다드',
#   '스타',
#   '코로나',
#   '코로나',
#   '데일',
#   '리코',
#   '디'],
#  ['장어', '스타', '코로나', '보양식'],
#  ['땜', '코로나', '제발'],
#  ['코로나', '약속'],
#  ['코로나',
#   '퇴근',
#   '집',
#   '최고',
#   '코로나',
#   '제발',
#   '아이패드',
#   '애플',
#   '교육',
#   '할인',
#   '앱등이',
#   '삶',
#   '가로수길'],
#  ['트레이닝',
#   '뚜',
#   '존예',
#   '코로나',
#   '핫',
#   '자체',
#   '핫',
#   '트레이닝',
#   '뚜',
#   '직원',
#   '완료',
#   '먼드',
#   '골지',
#   '후드',
#   '집업',
#   '먼드',
#   '골지',
#   '패드',
#   '탑',
#   '먼드',
#   '골지',
#   '밴딩',
#   '팬츠'],
#  ['코로나', '사람', '쭈꾸미', '용', '우동', '쭈꾸미', '군자', '코로나', '사람'],
#  ['얼굴', '야구', '운동선수', '년생', '디엠', '디엠', '스타', '야구', '스타', '코로나', '마스크', '스타'],
#  ['성남', '한의원', '코로나', '무색', '한의원', '대박', '사람'],
#  ['유머',
#   '코로나',
#   '포옹',
#   '방역',
#   '유머',
#   '백화점',
#   '댕댕',
#   '사랑',
#   '애기',
#   '강아지',
#   '고양이',
#   '냥',
#   '집사',
#   '남친',
#   '여친',
#   '아기',
#   '여행',
#   '운동',
#   '연애',
#   '육아'],
#  ['운명',
#   '사랑',
#   '성혼',
#   '마지막',
#   '절차',
#   '에스',
#   '노블',
#   '에로스',
#   '프',
#   '쉬케',
#   '집안',
#   '에스',
#   '노블',
#   '니',
#   '위',
#   '프리미엄',
#   '맞춤',
#   '서비스',
#   '에스',
#   '노블',
#   '상의',
#   '결혼',
#   '노블',
#   '결혼',
#   '정보',
#   '회사',
#   '노블레스',
#   '결혼',
#   '노블',
#   '전문',
#   '결혼',
#   '정보',
#   '업체',
#   '인연',
#   '맞선',
#   '재혼',
#   '재혼',
#   '전문',
#   '전문직',
#   '노블',
#   '결혼',
#   '정보',
#   '노블',
#   '결혼',
#   '정보',
#   '업체',
#   '소개팅',
#   '노블',
#   '타임',
#   '노블',
#   '제이노블',
#   '퍼플',
#   '스',
#   '디',
#   '노블',
#   '르',
#   '매리',
#   '청담동',
#   '선물',
#   '코로나',
#   '상류층',
#   '하이',
#   '클래스',
#   '하이엔드'],
#  ['자전거',
#   '타고',
#   '봄날',
#   '크리에이터',
#   '슬로시티',
#   '하동',
#   '밤',
#   '불빛',
#   '연인',
#   '코로나',
#   '시국',
#   '마스크',
#   '꼭꼭',
#   '산책',
#   '하동',
#   '폐',
#   '철도',
#   '공원',
#   '빛',
#   '슬로시티',
#   '하동',
#   '하동',
#   '여행',
#   '크리에이터',
#   '급구',
#   '코로나',
#   '마스크',
#   '꼭꼭'],
#  ['가지',
#   '컬러',
#   '트레이닝복',
#   '봄',
#   '신상',
#   '데끼',
#   '투맨',
#   '조거',
#   '팬츠',
#   '츄리닝',
#   '운동',
#   '남자',
#   '코',
#   '디스',
#   '패션',
#   '피플',
#   '부산',
#   '쇼핑몰',
#   '대한민국',
#   '오프라인',
#   '심심',
#   '코로나'],
#  ['주인공', '마스크', '코로나', '기전', '렉'],
#  ['죰', '코로나'],
#  ['토요일', '금요일', '팔공산', '코로나', '미세먼지', '화보'],
#  ['야구', '운동선수', '년생', '디엠', '디엠', '스타', '야구', '스타', '코로나', '마스크', '스타'],
#  ['집', '협조', '일도'],
#  ['리틀',
#   '넥',
#   '청담',
#   '목표',
#   '달성',
#   '만남',
#   '매달',
#   '매년',
#   '머리',
#   '파',
#   '뿌리',
#   '성장',
#   '대접',
#   '리더',
#   '인연',
#   '청담',
#   '맛집',
#   '도산',
#   '공원',
#   '맛집',
#   '코로나'],
#  ['욕기',
#   '타임',
#   '어케',
#   '감',
#   '코로나',
#   '불어',
#   '다이어트',
#   '아무',
#   '말리',
#   '푸드파이터',
#   '와인',
#   '치즈',
#   '코로나',
#   '욕기',
#   '멘붕',
#   '다이어트',
#   '치맥'],
#  ['첫',
#   '출근',
#   '순금',
#   '명함',
#   '입사',
#   '기념',
#   '돈',
#   '입사',
#   '코로나',
#   '첫출근',
#   '회사원',
#   '앞',
#   '금값',
#   '라라'],
#  ['미리', '생일', '축하', '어린이집', '등원', '형아', '마스크', '필수', '코로나'],
#  ['라인',
#   '나이',
#   '구애',
#   '코스프레',
#   '제복',
#   '직업',
#   '계통',
#   '중점',
#   '구합',
#   '니',
#   '염두',
#   '에이전시',
#   '수수료',
#   '요구',
#   '외모',
#   '타투',
#   '흉터',
#   '상관',
#   '아시',
#   '디엠',
#   '요기',
#   '본급',
#   '협의',
#   '스폰',
#   '스폰서',
#   '부업',
#   '대출',
#   '목돈',
#   '패션',
#   '대학생',
#   '고등학생',
#   '코디',
#   '뷰티',
#   '카페',
#   '코로나',
#   '알바',
#   '모델',
#   '페이',
#   '모델',
#   '학생',
#   '돌싱',
#   '육아',
#   '부업',
#   '코스프레',
#   '코스',
#   '간호사',
#   '스튜디어스',
#   '대출',
#   '승무원',
#   '간호사',
#   '필라테스',
#   '타투',
#   '헬스',
#   '트레이너'],
#  ['경주',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '객실',
#   '푸른',
#   '동해',
#   '바다',
#   '볼',
#   '자연',
#   '움',
#   '음',
#   '국적',
#   '풍경',
#   '낭만',
#   '분위기',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '인피니티',
#   '수영장',
#   '신수',
#   '공급',
#   '시스템',
#   '절기',
#   '도의',
#   '미온수',
#   '선택',
#   '결제',
#   '입실',
#   '내내',
#   '시간제',
#   '한과',
#   '미온수',
#   '요금',
#   '퇴',
#   '동해',
#   '바다',
#   '일출',
#   '일몰',
#   '감상',
#   '물놀이',
#   '객실',
#   '인테리어',
#   '자랑',
#   '객실',
#   '내부',
#   '객실',
#   '스파',
#   '시설',
#   '하루',
#   '피로',
#   '풀',
#   '층',
#   '층',
#   '인피니티',
#   '온수',
#   '수영장',
#   '하늘',
#   '그네',
#   '천상',
#   '의문',
#   '포토',
#   '존',
#   '인생',
#   '샷',
#   '환상',
#   '동해',
#   '바다',
#   '오션',
#   '뷰',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '시설',
#   '여행',
#   '선물',
#   '대형',
#   '스마트',
#   '벽',
#   '걸이',
#   '천정',
#   '에어컨',
#   '와이파이',
#   '올레',
#   '설치',
#   '여행지',
#   '최소',
#   '샵앤',
#   '렛풀',
#   '빌라',
#   '펜션',
#   '방문',
#   '여행',
#   '만족도',
#   '보이',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '대중교통',
#   '이용',
#   '손님',
#   '사전',
#   '감포',
#   '터미널',
#   '펜션',
#   '픽업',
#   '서비스',
#   '운영',
#   '중이',
#   '랍',
#   '탁트인',
#   '오션',
#   '뷰',
#   '휴가',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '추억',
#   '홈페이지',
#   '경주',
#   '펜션',
#   '경주',
#   '풀',
#   '빌라',
#   '대구',
#   '비키니',
#   '스파',
#   '펜션',
#   '애견',
#   '펜션',
#   '애견',
#   '펜션',
#   '경주',
#   '펜션',
#   '경주',
#   '풀',
#   '빌라',
#   '경주',
#   '숙소',
#   '졸업여행',
#   '경주',
#   '곳',
#   '경주',
#   '커플',
#   '여행',
#   '경주',
#   '펜션',
#   '포항',
#   '겨울',
#   '여행',
#   '코로나',
#   '국내',
#   '풀',
#   '빌라',
#   '울산',
#   '서울',
#   '경주',
#   '부산',
#   '국내',
#   '여행',
#   '모델'],
#  ['카페'],
#  ['경주',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '객실',
#   '푸른',
#   '동해',
#   '바다',
#   '볼',
#   '자연',
#   '움',
#   '음',
#   '국적',
#   '풍경',
#   '낭만',
#   '분위기',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '인피니티',
#   '수영장',
#   '신수',
#   '공급',
#   '시스템',
#   '절기',
#   '도의',
#   '미온수',
#   '선택',
#   '결제',
#   '입실',
#   '내내',
#   '시간제',
#   '한과',
#   '미온수',
#   '요금',
#   '퇴',
#   '동해',
#   '바다',
#   '일출',
#   '일몰',
#   '감상',
#   '물놀이',
#   '객실',
#   '인테리어',
#   '자랑',
#   '객실',
#   '내부',
#   '객실',
#   '스파',
#   '시설',
#   '하루',
#   '피로',
#   '풀',
#   '층',
#   '층',
#   '인피니티',
#   '온수',
#   '수영장',
#   '하늘',
#   '그네',
#   '천상',
#   '의문',
#   '포토',
#   '존',
#   '인생',
#   '샷',
#   '환상',
#   '동해',
#   '바다',
#   '오션',
#   '뷰',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '시설',
#   '여행',
#   '선물',
#   '대형',
#   '스마트',
#   '벽',
#   '걸이',
#   '천정',
#   '에어컨',
#   '와이파이',
#   '올레',
#   '설치',
#   '여행지',
#   '최소',
#   '샵앤',
#   '렛풀',
#   '빌라',
#   '펜션',
#   '방문',
#   '여행',
#   '만족도',
#   '보이',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '대중교통',
#   '이용',
#   '손님',
#   '사전',
#   '감포',
#   '터미널',
#   '펜션',
#   '픽업',
#   '서비스',
#   '운영',
#   '중이',
#   '랍',
#   '탁트인',
#   '오션',
#   '뷰',
#   '휴가',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '추억',
#   '홈페이지',
#   '경주',
#   '펜션',
#   '경주',
#   '풀',
#   '빌라',
#   '대구',
#   '비키니',
#   '스파',
#   '펜션',
#   '애견',
#   '펜션',
#   '애견',
#   '펜션',
#   '경주',
#   '펜션',
#   '경주',
#   '풀',
#   '빌라',
#   '경주',
#   '숙소',
#   '졸업여행',
#   '경주',
#   '곳',
#   '경주',
#   '커플',
#   '여행',
#   '경주',
#   '펜션',
#   '포항',
#   '겨울',
#   '여행',
#   '코로나',
#   '국내',
#   '풀',
#   '빌라',
#   '울산',
#   '서울',
#   '경주',
#   '부산',
#   '국내',
#   '여행',
#   '모델'],
#  ['안녕', '팬데믹', '코로나', '젠', '화이팅'],
#  ['헤르츠',
#   '뮤직',
#   '스튜디오',
#   '헤르츠',
#   '뮤직',
#   '스튜디오',
#   '남부',
#   '터미널',
#   '연습실',
#   '서초동',
#   '예술의전당',
#   '코로나',
#   '소독',
#   '손씻기',
#   '피아노',
#   '상태',
#   '최상급',
#   '수금',
#   '청소',
#   '청소',
#   '신',
#   '연세대학교',
#   '입시',
#   '퇴근',
#   '귀가',
#   '방',
#   '주차',
#   '헤르츠',
#   '뮤직',
#   '스튜디오',
#   '내일',
#   '최선'],
#  ['경주',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '객실',
#   '푸른',
#   '동해',
#   '바다',
#   '볼',
#   '자연',
#   '움',
#   '음',
#   '국적',
#   '풍경',
#   '낭만',
#   '분위기',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '인피니티',
#   '수영장',
#   '신수',
#   '공급',
#   '시스템',
#   '절기',
#   '도의',
#   '미온수',
#   '선택',
#   '결제',
#   '입실',
#   '내내',
#   '시간제',
#   '한과',
#   '미온수',
#   '요금',
#   '퇴',
#   '동해',
#   '바다',
#   '일출',
#   '일몰',
#   '감상',
#   '물놀이',
#   '객실',
#   '인테리어',
#   '자랑',
#   '객실',
#   '내부',
#   '객실',
#   '스파',
#   '시설',
#   '하루',
#   '피로',
#   '풀',
#   '층',
#   '층',
#   '인피니티',
#   '온수',
#   '수영장',
#   '하늘',
#   '그네',
#   '천상',
#   '의문',
#   '포토',
#   '존',
#   '인생',
#   '샷',
#   '환상',
#   '동해',
#   '바다',
#   '오션',
#   '뷰',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '시설',
#   '여행',
#   '선물',
#   '대형',
#   '스마트',
#   '벽',
#   '걸이',
#   '천정',
#   '에어컨',
#   '와이파이',
#   '올레',
#   '설치',
#   '여행지',
#   '최소',
#   '샵앤',
#   '렛풀',
#   '빌라',
#   '펜션',
#   '방문',
#   '여행',
#   '만족도',
#   '보이',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '펜션',
#   '대중교통',
#   '이용',
#   '손님',
#   '사전',
#   '감포',
#   '터미널',
#   '펜션',
#   '픽업',
#   '서비스',
#   '운영',
#   '중이',
#   '랍',
#   '탁트인',
#   '오션',
#   '뷰',
#   '휴가',
#   '샵앤플렛',
#   '풀',
#   '빌라',
#   '추억',
#   '홈페이지',
#   '경주',
#   '펜션',
#   '경주',
#   '풀',
#   '빌라',
#   '대구',
#   '비키니',
#   '스파',
#   '펜션',
#   '애견',
#   '펜션',
#   '애견',
#   '펜션',
#   '경주',
#   '펜션',
#   '경주',
#   '풀',
#   '빌라',
#   '경주',
#   '숙소',
#   '졸업여행',
#   '경주',
#   '곳',
#   '경주',
#   '커플',
#   '여행',
#   '경주',
#   '펜션',
#   '포항',
#   '겨울',
#   '여행',
#   '코로나',
#   '국내',
#   '풀',
#   '빌라',
#   '울산',
#   '서울',
#   '경주',
#   '부산',
#   '국내',
#   '여행',
#   '모델'],
#  ['자기애',
#   '최강',
#   '고초',
#   '긍정',
#   '자존감',
#   '자기애',
#   '바닥',
#   '별로',
#   '다난',
#   '안',
#   '졋었',
#   '몸',
#   '마음가짐',
#   '정신건강',
#   '밥',
#   '밥',
#   '짱',
#   '사랑',
#   '해도',
#   '사람',
#   '는걸'],
#  ['정말',
#   '가정',
#   '보육',
#   '에그타르트',
#   '원피스',
#   '맛집',
#   '쇼핑몰',
#   '쇼핑몰',
#   '쇼핑몰',
#   '쇼핑몰',
#   '쇼핑몰',
#   '하원',
#   '시오',
#   '마켓',
#   '딸딸맘',
#   '코로나'],
#  ['카페', '나가야', '공부', '스타'],
#  ['유',
#   '바디',
#   '배',
#   '방점',
#   '어깨',
#   '운동',
#   '토',
#   '항상',
#   '운동',
#   '카톡',
#   '유',
#   '바디',
#   '천안',
#   '헬스',
#   '아산',
#   '헬스',
#   '배방',
#   '헬스',
#   '탕정헬스',
#   '불당',
#   '헬스장',
#   '다이어트',
#   '헬창',
#   '헬린',
#   '바디',
#   '프로필',
#   '식단',
#   '운동',
#   '운동',
#   '남자',
#   '아산',
#   '맛집',
#   '아산',
#   '카페',
#   '운동',
#   '맛집',
#   '몸',
#   '스타',
#   '헬',
#   '스타',
#   '운동',
#   '스타',
#   '럽',
#   '스타',
#   '운동',
#   '사랑',
#   '코로나',
#   '헬스장'],
#  ['코로나', '언니', '출근', '하자', '코로나', '복귀', '개', '짜증'],
#  ['재미나', '코로나', '인칭', '스파링', '영상'],
#  ['게판',
#   '분전',
#   '티비',
#   '심진화',
#   '김원효',
#   '효도',
#   '먹방',
#   '보고',
#   '멀리',
#   '어머님께',
#   '게',
#   '드렷',
#   '코로나',
#   '시절',
#   '멀리',
#   '부모님',
#   '게',
#   '눌',
#   '마음',
#   '걸렷는데',
#   '나마',
#   '마음',
#   '집게',
#   '꿀',
#   '진짜',
#   '게꿀',
#   '보신',
#   '부모님',
#   '젠',
#   '차례',
#   '와우',
#   '대게',
#   '땟깔',
#   '발라',
#   '게장',
#   '밥',
#   '코로나',
#   '물럿거',
#   '역시',
#   '심진화',
#   '김원효',
#   '짱짱',
#   '엄지',
#   '착',
#   '최상',
#   '게',
#   '사장',
#   '대게',
#   '맛집',
#   '집게',
#   '꿀',
#   '신선',
#   '보증',
#   '맛',
#   '보증',
#   '게판',
#   '재주',
#   '알람',
#   '필수',
#   '부모님',
#   '체력',
#   '증진',
#   '게섯',
#   '새우',
#   '대게',
#   '가요',
#   '대게',
#   '가요'],
#  ['나이',
#   '씁슬해',
#   '코로나',
#   '저리',
#   '가라',
#   '인생',
#   '생존',
#   '신고',
#   '스타',
#   '깜깜',
#   '얼공',
#   '스타',
#   '스타',
#   '인스타',
#   '주의',
#   '대전',
#   '공주',
#   '천안',
#   '세종'],
#  ['앞니',
#   '개',
#   '등원',
#   '머리',
#   '이빨',
#   '역시',
#   '애가',
#   '유천',
#   '가야',
#   '서로',
#   '애뜻',
#   '보쟈',
#   '코로나',
#   '육아',
#   '아들',
#   '청말띠',
#   '아스타'],
#  ['코로나'],
#  ['건강검진',
#   '위대',
#   '내시경',
#   '검사',
#   '건강',
#   '염려',
#   '증',
#   '국가',
#   '건강검진',
#   '은',
#   '한번',
#   '위',
#   '내시경',
#   '대장',
#   '내시경',
#   '신청',
#   '원래',
#   '코로나',
#   '결정'],
#  ['치명', '년생', '코로나', '음악가', '여행', '스타', '팔로', '우미', '인스타', '모델', '치명'],
#  ['얌',
#   '감기',
#   '인천',
#   '구월동',
#   '구월동',
#   '칵테일',
#   '구월동',
#   '몰트',
#   '위스키',
#   '혼술',
#   '분위기',
#   '몰트',
#   '바',
#   '몰트',
#   '위스키',
#   '종',
#   '코로나'],
#  ['코로나',
#   '요가',
#   '오픈',
#   '전문',
#   '방역',
#   '업체',
#   '통해',
#   '소독',
#   '진행',
#   '가정',
#   '집',
#   '방역',
#   '업체',
#   '통해',
#   '진행',
#   '신분',
#   '아래',
#   '홈페이지',
#   '카톡',
#   '홈페이지',
#   '주소',
#   '멸균',
#   '카카오',
#   '톡',
#   '살균',
#   '소독',
#   '멸균',
#   '공간',
#   '멸균',
#   '피톤',
#   '치드',
#   '항균',
#   '코팅',
#   '광촉매',
#   '포름알데히드',
#   '새집',
#   '증후군',
#   '청소',
#   '멸균',
#   '맨',
#   '엠',
#   '지엠',
#   '솔루션',
#   '코로나',
#   '방역',
#   '코로나',
#   '방역',
#   '코로나',
#   '코로나',
#   '바이러스',
#   '퇴치',
#   '바이러스',
#   '세균',
#   '세균',
#   '퇴치',
#   '코로나',
#   '코로나',
#   '선택',
#   '필수',
#   '아토피',
#   '실내',
#   '공기',
#   '건강',
#   '호흡기',
#   '질환'],
#  ['저녁식사',
#   '코로나',
#   '시대',
#   '서울',
#   '외식',
#   '몬가하',
#   '쿠팡',
#   '이용',
#   '놈',
#   '곱창',
#   '대창',
#   '염통',
#   '막창',
#   '맛',
#   '양념',
#   '게장',
#   '고기',
#   '집',
#   '저녁식사',
#   '코로나',
#   '곱창',
#   '대창',
#   '막창',
#   '염통',
#   '양념',
#   '게장',
#   '쿠팡',
#   '울릉도',
#   '서울'],
#  ['호텔', '직원', '초'],
#  [],
#  ['쌩얼'],
#  ['강제', '집', '돌이', '코', '라나', '코로나'],
#  ['코로나', '제발', '얘'],
#  ['주도',
#   '한주',
#   '정말',
#   '고생',
#   '달',
#   '백신',
#   '접종',
#   '뉴스',
#   '점점',
#   '코로나',
#   '전의',
#   '일상생활',
#   '마음',
#   '점점',
#   '듭',
#   '주식',
#   '주식',
#   '듭',
#   '주식',
#   '하루',
#   '단타',
#   '정도',
#   '수익',
#   '만원',
#   '돈',
#   '만원',
#   '금액',
#   '수익',
#   '내야',
#   '계속',
#   '목표',
#   '초반',
#   '투',
#   '자금',
#   '항상',
#   '스스로',
#   '목표',
#   '주식',
#   '듭',
#   '가끔',
#   '원칙',
#   '공부',
#   '통',
#   '종목',
#   '선정',
#   '순간',
#   '욕심',
#   '욕심',
#   '화',
#   '행위',
#   '안',
#   '화장',
#   '관련',
#   '주가',
#   '상승',
#   '중국',
#   '설날',
#   '슬슬',
#   '화장품',
#   '관련',
#   '주식',
#   '평가',
#   '하니',
#   '관련',
#   '상승',
#   '코로나',
#   '식당',
#   '여러',
#   '곳',
#   '자금',
#   '주식',
#   '부동산',
#   '투자',
#   '가운데',
#   '인터넷',
#   '쇼핑',
#   '코로나',
#   '이전',
#   '상승',
#   '주식',
#   '상승',
#   '종목',
#   '선정',
#   '볼',
#   '화장품',
#   '관련',
#   '주식',
#   '쇼핑',
#   '관련',
#   '주식',
#   '자주',
#   '눈',
#   '볼',
#   '필요',
#   '한주',
#   '고생',
#   '주말',
#   '아무',
#   '코로나',
#   '피',
#   '일모',
#   '주식',
#   '주식',
#   '스타',
#   '주식',
#   '공부',
#   '주식',
#   '투자',
#   '주식',
#   '초보',
#   '주식',
#   '단타',
#   '주식',
#   '정보',
#   '주식시장',
#   '주식',
#   '차트',
#   '주식',
#   '매매',
#   '주식',
#   '종목',
#   '아모레퍼시픽',
#   '아모레',
#   '코로나',
#   '코로나'],
#  ['코로나',
#   '전선',
#   '활약',
#   '간호사',
#   '선배',
#   '응원',
#   '린지',
#   '간대협',
#   '간호',
#   '대학',
#   '학생',
#   '협회',
#   '코로나',
#   '극복',
#   '간호사',
#   '간호학'],
#  ['마스크'],
#  ['헬스장', '일차', '아무', '걷기', '코로나', '제발'],
#  ['잇츠짐',
#   '굿바이',
#   '어서',
#   '신축년',
#   '흰소',
#   '띠',
#   '맞이',
#   '잇츠짐',
#   '프로모션',
#   '할인',
#   '혜택',
#   '헬스',
#   '스피닝',
#   '프리미엄',
#   '이용권',
#   '할인',
#   '혜택',
#   '비대',
#   '등록',
#   '신청',
#   '사전',
#   '신청',
#   '참고',
#   '아래',
#   '번호',
#   '주시',
#   '친철',
#   '제임스',
#   '짐',
#   '실시간',
#   '정부',
#   '지침',
#   '진행',
#   '상황',
#   '모니터링',
#   '운동',
#   '환경',
#   '조성',
#   '대비',
#   '코로나',
#   '예방',
#   '손씻기',
#   '마스크',
#   '착용',
#   '손소독',
#   '위생',
#   '적극',
#   '협조',
#   '실천',
#   '모이',
#   '예방',
#   '꼭',
#   '실천',
#   '울산',
#   '바디',
#   '프로필',
#   '다이어트',
#   '제임스',
#   '짐',
#   '산점',
#   '울산',
#   '잇츠',
#   '짐',
#   '잇츠짐',
#   '울산',
#   '핫',
#   '울산',
#   '울산',
#   '헬스',
#   '울산',
#   '헬스장',
#   '울산',
#   '피티',
#   '울산',
#   '필라테스',
#   '울산',
#   '요가',
#   '울산',
#   '기구',
#   '필라테스',
#   '울산',
#   '다이어트',
#   '울산',
#   '바디',
#   '프로필',
#   '울산',
#   '키즈',
#   '스피닝',
#   '맞이',
#   '신축년',
#   '신축년',
#   '흰소',
#   '띠',
#   '유사',
#   '코로나',
#   '극복',
#   '코로나',
#   '코로나',
#   '린지',
#   '린지'],
#  ['잇츠짐',
#   '굿바이',
#   '어서',
#   '신축년',
#   '흰소',
#   '띠',
#   '맞이',
#   '잇츠짐',
#   '프로모션',
#   '할인',
#   '혜택',
#   '헬스',
#   '스피닝',
#   '프리미엄',
#   '이용권',
#   '할인',
#   '혜택',
#   '비대',
#   '등록',
#   '신청',
#   '사전',
#   '신청',
#   '참고',
#   '아래',
#   '번호',
#   '주시',
#   '친철',
#   '제임스',
#   '짐',
#   '실시간',
#   '정부',
#   '지침',
#   '진행',
#   '상황',
#   '모니터링',
#   '운동',
#   '환경',
#   '조성',
#   '대비',
#   '코로나',
#   '예방',
#   '손씻기',
#   '마스크',
#   '착용',
#   '손소독',
#   '위생',
#   '적극',
#   '협조',
#   '실천',
#   '모이',
#   '예방',
#   '꼭',
#   '실천',
#   '울산',
#   '바디',
#   '프로필',
#   '다이어트',
#   '제임스',
#   '짐',
#   '산점',
#   '울산',
#   '잇츠',
#   '짐',
#   '잇츠짐',
#   '울산',
#   '핫',
#   '울산',
#   '울산',
#   '헬스',
#   '울산',
#   '헬스장',
#   '울산',
#   '피티',
#   '울산',
#   '필라테스',
#   '울산',
#   '요가',
#   '울산',
#   '기구',
#   '필라테스',
#   '울산',
#   '다이어트',
#   '울산',
#   '바디',
#   '프로필',
#   '울산',
#   '키즈',
#   '스피닝',
#   '맞이',
#   '신축년',
#   '신축년',
#   '흰소',
#   '띠',
#   '유사',
#   '코로나',
#   '극복',
#   '코로나',
#   '코로나',
#   '린지',
#   '린지'],
#  ['스무살', '벌써', '달'],
#  ['둘이서',
#   '맥주',
#   '떡볶이',
#   '맛',
#   '요',
#   '대구',
#   '간식',
#   '맛스타',
#   '스타',
#   '집밥',
#   '럽',
#   '스타',
#   '부부',
#   '커플',
#   '신랑',
#   '사랑',
#   '금요일',
#   '평일',
#   '코로나'],
#  ['코로나',
#   '집',
#   '피부관리',
#   '정직',
#   '매니저',
#   '독일인',
#   '셀덤',
#   '인셀덤',
#   '독일',
#   '베를린',
#   '셀덤',
#   '인셀덤',
#   '베를린',
#   '밀착',
#   '케어',
#   '인셀덤',
#   '유지민',
#   '탈모',
#   '샴푸'],
#  [],
#  ['립밤', '거', '해쥬세', '팔로', '우미', '다이렉트', '연락', '연락', '코로나'],
#  ['삼계탕',
#   '맛',
#   '대구',
#   '단골',
#   '맛집',
#   '점심',
#   '해장',
#   '스타',
#   '월요일',
#   '헬',
#   '요일',
#   '평일',
#   '눈',
#   '코로나'],
#  ['전복',
#   '닭죽',
#   '삼겹살',
#   '주물럭',
#   '주방',
#   '대구',
#   '집밥',
#   '홈쿡',
#   '맛스타',
#   '스타',
#   '가족',
#   '럽',
#   '스타',
#   '사랑',
#   '코로나',
#   '어제',
#   '토요일',
#   '불토',
#   '일요일',
#   '주말'],
#  ['파스텔', '심플', '투', '피스', '잠옷', '핑크', '그린', '버전', '용'],
#  ['코로나', '개', '십대', '첫', '생일', '유재현', '신일', '코로나', '안녕', '댓', '팔로', '우미'],
#  ['년도', '짜장면'],
#  ['코로나',
#   '꼭',
#   '울',
#   '꿍',
#   '마스크',
#   '착용',
#   '코로나',
#   '마스크',
#   '필수',
#   '생명',
#   '마스크',
#   '캣',
#   '스타'],
#  ['일산',
#   '앞마당',
#   '오리',
#   '집',
#   '훈제',
#   '오리',
#   '도리',
#   '주물',
#   '럭',
#   '식이',
#   '망치',
#   '코로나',
#   '가든',
#   '일산',
#   '오리',
#   '집',
#   '앞마당',
#   '코로나',
#   '오리',
#   '훈제',
#   '오리',
#   '주물',
#   '럭',
#   '자주색',
#   '쟈켓',
#   '파란색',
#   '쟈켓',
#   '아이스하키',
#   '해머',
#   '홍시',
#   '단시',
#   '플랜',
#   '플랜',
#   '동의보감',
#   '선후배',
#   '사이',
#   '말'],
#  ['휴강',
#   '돈',
#   '돈',
#   '청결',
#   '방역',
#   '더욱',
#   '대비',
#   '환경',
#   '운동',
#   '플라잉',
#   '스토리',
#   '노력',
#   '코로나',
#   '확산',
#   '예방',
#   '안전',
#   '정부',
#   '방침',
#   '협조',
#   '상황',
#   '종결',
#   '마음',
#   '항상',
#   '건강',
#   '유의'],
#  ['목욕탕', '쫌', '코로나', '계속', '목욕탕', '목욕탕', '답', '집', '코로나', '포항'],
#  ['못', '코로나', '코로나', '조심', '집', '집콕', '스타', '단체사진', '년생'],
#  ['잇츠짐',
#   '굿바이',
#   '어서',
#   '신축년',
#   '흰소',
#   '띠',
#   '맞이',
#   '잇츠짐',
#   '프로모션',
#   '할인',
#   '혜택',
#   '헬스',
#   '스피닝',
#   '프리미엄',
#   '이용권',
#   '할인',
#   '혜택',
#   '비대',
#   '등록',
#   '신청',
#   '사전',
#   '신청',
#   '참고',
#   '아래',
#   '번호',
#   '주시',
#   '친철',
#   '제임스',
#   '짐',
#   '실시간',
#   '정부',
#   '지침',
#   '진행',
#   '상황',
#   '모니터링',
#   '운동',
#   '환경',
#   '조성',
#   '대비',
#   '코로나',
#   '예방',
#   '손씻기',
#   '마스크',
#   '착용',
#   '손소독',
#   '위생',
#   '적극',
#   '협조',
#   '실천',
#   '모이',
#   '예방',
#   '꼭',
#   '실천',
#   '울산',
#   '바디',
#   '프로필',
#   '다이어트',
#   '제임스',
#   '짐',
#   '산점',
#   '울산',
#   '잇츠',
#   '짐',
#   '잇츠짐',
#   '울산',
#   '핫',
#   '울산',
#   '울산',
#   '헬스',
#   '울산',
#   '헬스장',
#   '울산',
#   '피티',
#   '울산',
#   '필라테스',
#   '울산',
#   '요가',
#   '울산',
#   '기구',
#   '필라테스',
#   '울산',
#   '다이어트',
#   '울산',
#   '바디',
#   '프로필',
#   '울산',
#   '키즈',
#   '스피닝',
#   '맞이',
#   '신축년',
#   '신축년',
#   '흰소',
#   '띠',
#   '유사',
#   '코로나',
#   '극복',
#   '코로나',
#   '코로나',
#   '린지',
#   '린지'],
#  ['맑은',
#   '스킨',
#   '용인역',
#   '북점',
#   '소독',
#   '마감',
#   '토요일',
#   '일요일',
#   '월요일',
#   '주말',
#   '제로',
#   '인',
#   '인',
#   '커플',
#   '회',
#   '용품',
#   '폐기',
#   '시술',
#   '모든',
#   '기구',
#   '소독',
#   '오픈',
#   '독실',
#   '시합',
#   '항시',
#   '소독',
#   '실시',
#   '금',
#   '토요일',
#   '일요일',
#   '공휴일',
#   '휴무',
#   '실소',
#   '독',
#   '연무',
#   '소독',
#   '피톤',
#   '치드',
#   '코로나',
#   '피부관리',
#   '스킨',
#   '케어',
#   '역',
#   '북동',
#   '피부관리',
#   '처인구',
#   '피부관리',
#   '용인',
#   '피부관리',
#   '용인',
#   '피부관리',
#   '곳',
#   '청결',
#   '맛집',
#   '살균',
#   '소독',
#   '피부관리',
#   '곳',
#   '뷰티',
#   '뷰티',
#   '스타',
#   '천연',
#   '피부관리',
#   '맑은',
#   '스킨',
#   '용인역',
#   '북점',
#   '맑은',
#   '스킨',
#   '피부관리',
#   '스킨',
#   '케어',
#   '트러블',
#   '케어',
#   '보습',
#   '케어',
#   '탄력',
#   '케어',
#   '명지대',
#   '피부관리',
#   '홈',
#   '케어'],
#  ['때매', '청춘', '코로나'],
#  ['잔', '머리', '짱'],
#  ['몸', '달', '원상', '복구', '코로나', '사화', '헬린'],
#  ['코로나',
#   '코로나',
#   '옹',
#   '세월호',
#   '추모',
#   '관',
#   '코로나',
#   '냐옹',
#   '인천',
#   '가족',
#   '공원',
#   '세월호',
#   '추모',
#   '관',
#   '고양이',
#   '추모',
#   '관'],
#  ['생존',
#   '신고',
#   '맛스타',
#   '양고기',
#   '소식',
#   '아마',
#   '다음주',
#   '산행',
#   '부산',
#   '진해',
#   '용',
#   '맛집',
#   '부산',
#   '맛집',
#   '음식',
#   '양고기',
#   '또띠아',
#   '소주',
#   '진로',
#   '터',
#   '팔로',
#   '하단',
#   '인스타',
#   '맛스타',
#   '코로나',
#   '코로나',
#   '등산',
#   '산행'],
#  ['홈플러스',
#   '홈플러스',
#   '피자',
#   '치즈',
#   '피자',
#   '포장',
#   '피자',
#   '맛집',
#   '피자',
#   '피크',
#   '콜라',
#   '코카콜라',
#   '사이다',
#   '스프라이트',
#   '부천',
#   '소사',
#   '역곡',
#   '역곡동',
#   '역곡역',
#   '괴안동',
#   '부천',
#   '맛집',
#   '역곡',
#   '맛집',
#   '괴안동',
#   '맛집',
#   '맛집',
#   '먹방',
#   '배달',
#   '배민',
#   '배달',
#   '민족',
#   '코로나',
#   '쿠폰'],
#  ['바바리안', '크림', '도넛', '슈거', '파우더', '느낌', '랄', '골프', '시즌'],
#  ['건강검진',
#   '센터',
#   '입장',
#   '체온',
#   '간격',
#   '못',
#   '전날',
#   '만난',
#   '사람',
#   '임',
#   '시선',
#   '진료',
#   '재택',
#   '근무',
#   '음성',
#   '판정',
#   '증상',
#   '마스',
#   '킹',
#   '약',
#   '복용',
#   '안',
#   '열',
#   '코로나',
#   '삼성역',
#   '임',
#   '시선',
#   '진료',
#   '검사',
#   '음성',
#   '역시',
#   '유행',
#   '다해',
#   '직성',
#   '끝'],
#  ['운동', '케어', '걷기'],
#  ['간만',
#   '유튜브',
#   '창',
#   '찰',
#   '구독',
#   '셀프',
#   '세차장',
#   '셀프',
#   '세차',
#   '테라',
#   '워',
#   '영등포',
#   '밤바리',
#   '퇴근',
#   '밤바리',
#   '쏠투',
#   '할리데이비슨',
#   '바이크',
#   '포티',
#   '아이언',
#   '스',
#   '포스터',
#   '브레이크아웃',
#   '할리',
#   '바이크',
#   '스타',
#   '코로나',
#   '줄라이',
#   '식스',
#   '틴',
#   '홍대',
#   '코로나',
#   '여행',
#   '브이',
#   '로그',
#   '여행',
#   '라이딩',
#   '바이크',
#   '쏠투',
#   '바린',
#   '서울',
#   '창',
#   '찰',
#   '홍대'],
#  ['힐러리',
#   '클린턴',
#   '오바마',
#   '음모론',
#   '음모론',
#   '싹',
#   '팩트',
#   '음모론',
#   '음모론',
#   '팩트',
#   '뉴스',
#   '신문',
#   '음모론',
#   '온',
#   '역사',
#   '교과서',
#   '음모론',
#   '거짓말',
#   '기반',
#   '이기',
#   '다한',
#   '신문',
#   '미디어',
#   '갑자기',
#   '주식',
#   '대해',
#   '전망',
#   '무궁무진',
#   '무조건',
#   '주식',
#   '광고',
#   '진짜',
#   '주식',
#   '사기',
#   '기자',
#   '사라',
#   '식',
#   '결과',
#   '정',
#   '반대',
#   '다그',
#   '신문',
#   '미디어',
#   '보고',
#   '주식',
#   '매수',
#   '순간',
#   '주식',
#   '폭락',
#   '전주',
#   '세력',
#   '개미',
#   '물량',
#   '적극',
#   '활용',
#   '신문',
#   '미디어',
#   '기레기',
#   '푼돈',
#   '먹이',
#   '서지',
#   '기사',
#   '달라',
#   '속임수',
#   '기사',
#   '개미',
#   '낚시질',
#   '신문',
#   '미디어',
#   '집안',
#   '풍비박산',
#   '거지',
#   '주식',
#   '안',
#   '사람',
#   '주식',
#   '한강',
#   '간다',
#   '말',
#   '초',
#   '기사',
#   '거짓말',
#   '짝퉁',
#   '쓰레기',
#   '정보',
#   '진짜',
#   '정보',
#   '철떡',
#   '나름',
#   '목숨',
#   '열정',
#   '분석',
#   '거지',
#   '게',
#   '신문',
#   '미디어',
#   '위력',
#   '진실',
#   '세뇌',
#   '의심',
#   '여지',
#   '그냥',
#   '뇌구조',
#   '대한민국',
#   '뉴스',
#   '외모',
#   '좌파',
#   '편향',
#   '언론사',
#   '놈',
#   '싹',
#   '국민',
#   '거짓',
#   '정보',
#   '농락',
#   '죄',
#   '량',
#   '천년',
#   '광화문',
#   '산채',
#   '경제',
#   '문화',
#   '역사',
#   '사상',
#   '음모론',
#   '전쟁',
#   '질병',
#   '코로나',
#   '사회',
#   '유행',
#   '지식',
#   '칼',
#   '성제',
#   '준',
#   '이지성',
#   '얼음',
#   '사이다',
#   '스피카',
#   '스튜디오',
#   '방송국',
#   '연예계',
#   '가수',
#   '배우',
#   '드라마',
#   '영화',
#   '소설',
#   '테레사',
#   '인신매매',
#   '포털',
#   '네이버'],
#  ['진실',
#   '가수',
#   '제노',
#   '코로나',
#   '사기',
#   '코로나',
#   '사기',
#   '백신',
#   '부작용',
#   '코로나',
#   '백신',
#   '부작용',
#   '코로나',
#   '백신',
#   '반대',
#   '백신',
#   '반대',
#   '플랜',
#   '데믹',
#   '계획',
#   '팬데믹',
#   '코로나',
#   '백신',
#   '독극물',
#   '코로나',
#   '백신',
#   '코로나',
#   '백신',
#   '백신',
#   '코로나',
#   '감소',
#   '정책',
#   '코로나',
#   '백신',
#   '유전자',
#   '변형',
#   '물질',
#   '코로나',
#   '백신',
#   '생체',
#   '칩',
#   '최종',
#   '버전',
#   '코로나',
#   '백신',
#   '절대',
#   '코로나',
#   '백신',
#   '절대',
#   '반대',
#   '코로나',
#   '코로나',
#   '백신',
#   '코로나',
#   '백신',
#   '백신',
#   '빌게이츠',
#   '인구',
#   '감소',
#   '정책',
#   '신세계',
#   '질서',
#   '코로나',
#   '백신',
#   '짐승',
#   '표',
#   '짐승',
#   '표',
#   '살인',
#   '집단'],
#  ['어린이집',
#   '양갈래',
#   '곱슬',
#   '머리',
#   '단발',
#   '집',
#   '추노',
#   '화장실',
#   '아기',
#   '식탁',
#   '짤랐는데',
#   '움직',
#   '짜르',
#   '기도',
#   '여름',
#   '한번',
#   '짜르',
#   '아버님',
#   '미취',
#   '학',
#   '아동',
#   '개월',
#   '커트',
#   '엄마',
#   '미용사'],
#  ['전역', '사유', '이만기', '팩트', '깨알', '개그', '키키', '코로나', '십장생', '시바스리갈', '청춘'],
#  [],
#  ['인코브',
#   '싼타페',
#   '엠블럼',
#   '엠블럼',
#   '혼캡',
#   '휠캡',
#   '레터',
#   '링',
#   '색상',
#   '크롬',
#   '다크',
#   '크롬',
#   '인코브',
#   '해외',
#   '파트너',
#   '모집',
#   '해외',
#   '지사',
#   '설립',
#   '수출',
#   '유통업체',
#   '모집',
#   '창업',
#   '교육',
#   '인코브',
#   '엠블럼',
#   '인코브',
#   '엠블럼',
#   '싼타페',
#   '코로나',
#   '한가위',
#   '설날'],
#  ['갤럭시',
#   '노트',
#   '울트라',
#   '희망',
#   '정보',
#   '통신',
#   '개통',
#   '갤럭시',
#   '노트',
#   '울트라',
#   '브론즈',
#   '사은',
#   '품',
#   '희망',
#   '정보통',
#   '패턴',
#   '맞춤',
#   '통해',
#   '가계',
#   '통',
#   '신부',
#   '부담',
#   '희망',
#   '정보통',
#   '개통',
#   '끝',
#   '마음',
#   '필름',
#   '케이스',
#   '무상',
#   '교체',
#   '개통',
#   '무상',
#   '서비스',
#   '점검',
#   '문자',
#   '체크',
#   '갤럭시',
#   '울트라',
#   '개통',
#   '아이폰',
#   '개통',
#   '아이폰',
#   '미니',
#   '아이폰',
#   '프로',
#   '프로',
#   '맥스',
#   '최대',
#   '혜택',
#   '광산구',
#   '친절',
#   '매장'],
#  ['신랑',
#   '저녁',
#   '차려',
#   '주기',
#   '냉장고',
#   '자투리',
#   '야채',
#   '밥',
#   '오므라이스',
#   '소스',
#   '차돌박이',
#   '된장국',
#   '집밥',
#   '신혼',
#   '밥상',
#   '신혼부부',
#   '스타',
#   '스타',
#   '스타',
#   '맛스타',
#   '스타',
#   '요리',
#   '쿡스',
#   '코로나',
#   '오므라이스',
#   '홈쿡',
#   '주부',
#   '스타',
#   '가정식',
#   '부림',
#   '저녁',
#   '밥상',
#   '한식'],
#  [],
#  ['시즌',
#   '중',
#   '할인',
#   '월말',
#   '진행',
#   '봄',
#   '신상',
#   '슬랙스',
#   '청바지',
#   '안산',
#   '안산',
#   '옷가게',
#   '중앙',
#   '옷가게',
#   '안산',
#   '중앙',
#   '데일',
#   '리코',
#   '디',
#   '스타',
#   '뭐',
#   '입지',
#   '코로나',
#   '쇼핑몰',
#   '옷',
#   '봄옷',
#   '블로퍼',
#   '핸메',
#   '코트',
#   '핸드',
#   '메이드',
#   '니트',
#   '봄',
#   '신상',
#   '시즌',
#   '오프',
#   '고잔동',
#   '옷가게'],
#  ['웃음', '엄마', '면배', '한번', '소식', '동생'],
#  ['카페', '고시', '광주', '동명동', '손탁', '앤', '이허'],
#  ['함박눈', '마지막', '내일', '마음', '햅삐뉴이어'],
#  ['언니', '결혼', '축하', '겸', '모임', '전주', '송천동', '에코', '시티'],
#  ['명절'],
#  ['추캉스', '똑', '순이', '곱창', '연휴', '돈좀'],
#  ['전밍', '원픽', '긴머리', '시절'],
#  ['전자렌지',
#   '계란찜',
#   '옹',
#   '계란',
#   '개',
#   '멸치',
#   '다시다',
#   '물',
#   '부어',
#   '살살',
#   '준',
#   '전자렌지',
#   '초',
#   '고깃집',
#   '폭탄',
#   '계란찜',
#   '계란찜',
#   '옹',
#   '계란찜',
#   '자취',
#   '자취',
#   '요리',
#   '싱가폴',
#   '기숙사',
#   '한국',
#   '가지',
#   '코로나',
#   '방구',
#   '카페',
#   '야메',
#   '요리',
#   '스타'],
#  ['생일상',
#   '코로나',
#   '스타',
#   '집밥',
#   '홈쿡',
#   '스타',
#   '요리',
#   '스타',
#   '서울',
#   '대전',
#   '대구',
#   '부산',
#   '광주',
#   '거제',
#   '생일상'],
#  ['로드',
#   '팀',
#   '금요일',
#   '방송',
#   '확인',
#   '확인',
#   '주말',
#   '뉴스데스크',
#   '코로나',
#   '시국',
#   '청년',
#   '이야기',
#   '연속',
#   '기획',
#   '코로나',
#   '시대',
#   '청년',
#   '편',
#   '청년',
#   '실신',
#   '은',
#   '내일',
#   '저녁',
#   '뉴스데스크',
#   '확인'],
#  ['정신',
#   '아홉수',
#   '코로나',
#   '키',
#   '워드',
#   '정리',
#   '작년',
#   '이맘',
#   '회사',
#   '화이팅',
#   '하자',
#   '의기',
#   '투합',
#   '코로나',
#   '사태',
#   '군대',
#   '어린시절',
#   '가족',
#   '피아노',
#   '치면',
#   '안정',
#   '와중',
#   '평소',
#   '제로',
#   '콜라',
#   '코카콜라',
#   '주주',
#   '다행',
#   '게시',
#   '물',
#   '리기',
#   '추억',
#   '기록',
#   '하자'],
#  ['머리',
#   '어울',
#   '야구',
#   '운동선수',
#   '헤어',
#   '년생',
#   '디엠',
#   '디엠',
#   '스타',
#   '야구',
#   '스타',
#   '코로나',
#   '마스크',
#   '스티'],
#  ['댕댕', '케이크', '봄', '이아린'],
#  ['빛',
#   '나무',
#   '인스타',
#   '밤',
#   '공기',
#   '성',
#   '중국',
#   '공부',
#   '코로나',
#   '마스크',
#   '쑤저우',
#   '장쑤성',
#   '오강',
#   '이사'],
#  ['딸', '아빠'],
#  ['회', '신년', '회', '내추럴', '와인', '신년', '회', '정부', '지침', '모임', '구성원', '스타', '모임'],
#  ['갤럭시',
#   '출시',
#   '케어',
#   '서비스',
#   '비대',
#   '진행',
#   '코로나',
#   '갤럭시',
#   '비대',
#   '개통',
#   '휴대폰',
#   '모바일'],
#  ['시국', '여행', '못', '듯', '수영'],
#  ['요한계시록',
#   '선지자',
#   '금',
#   '예배',
#   '설교',
#   '통역',
#   '생중계',
#   '유튜브',
#   '페이스북',
#   '트위터',
#   '페리',
#   '스코프',
#   '트위치',
#   '코로나',
#   '사회',
#   '교회',
#   '예배',
#   '요한계시록',
#   '휴거',
#   '환란',
#   '회개',
#   '주님',
#   '예비',
#   '메시아'],
#  ['코로나', '버스킹'],
#  ['요한계시록',
#   '선지자',
#   '금',
#   '예배',
#   '설교',
#   '통역',
#   '생중계',
#   '유튜브',
#   '페이스북',
#   '트위터',
#   '페리',
#   '스코프',
#   '트위치',
#   '코로나',
#   '사회',
#   '교회',
#   '예배',
#   '요한계시록',
#   '휴거',
#   '환란',
#   '회개',
#   '주님',
#   '예비',
#   '메시아'],
#  ['갓',
#   '대게',
#   '맛',
#   '대게',
#   '죽변',
#   '대게',
#   '죽변항',
#   '울진',
#   '맛집',
#   '죽변',
#   '맛집',
#   '대게',
#   '대게',
#   '맛집',
#   '연말',
#   '파티',
#   '가족',
#   '모임',
#   '대게',
#   '찜',
#   '대게',
#   '택배',
#   '전국',
#   '택배',
#   '코로나',
#   '집',
#   '호캉스',
#   '폭주',
#   '홈파티',
#   '울진',
#   '육아',
#   '추억',
#   '코로나',
#   '운동',
#   '여행'],
#  ['요한계시록',
#   '선지자',
#   '금',
#   '예배',
#   '설교',
#   '통역',
#   '생중계',
#   '유튜브',
#   '페이스북',
#   '트위터',
#   '페리',
#   '스코프',
#   '트위치',
#   '코로나',
#   '사회',
#   '교회',
#   '예배',
#   '요한계시록',
#   '휴거',
#   '환란',
#   '회개',
#   '주님',
#   '예비',
#   '메시아'],
#  ['요한계시록',
#   '선지자',
#   '금',
#   '예배',
#   '설교',
#   '통역',
#   '생중계',
#   '유튜브',
#   '페이스북',
#   '트위터',
#   '페리',
#   '스코프',
#   '트위치',
#   '코로나',
#   '사회',
#   '교회',
#   '예배',
#   '요한계시록',
#   '휴거',
#   '환란',
#   '회개',
#   '주님',
#   '예비',
#   '메시아'],
#  ['요한계시록',
#   '선지자',
#   '금',
#   '예배',
#   '설교',
#   '통역',
#   '생중계',
#   '유튜브',
#   '페이스북',
#   '트위터',
#   '페리',
#   '스코프',
#   '트위치',
#   '코로나',
#   '사회',
#   '교회',
#   '예배',
#   '요한계시록',
#   '휴거',
#   '환란',
#   '회개',
#   '주님',
#   '예비',
#   '메시아'],
#  ['코로나', '일만', '쥬'],
#  ['요한계시록',
#   '선지자',
#   '금',
#   '예배',
#   '설교',
#   '통역',
#   '생중계',
#   '유튜브',
#   '페이스북',
#   '트위터',
#   '페리',
#   '스코프',
#   '트위치',
#   '코로나',
#   '사회',
#   '교회',
#   '예배',
#   '요한계시록',
#   '휴거',
#   '환란',
#   '회개',
#   '주님',
#   '예비',
#   '메시아'],
#  ['정민', '납치'],
#  [],
#  [],
#  ['년도', '제주도', '갈수', '징', '코로나', '대전', '고등학생'],
#  ['요한계시록',
#   '선지자',
#   '금',
#   '예배',
#   '설교',
#   '통역',
#   '생중계',
#   '유튜브',
#   '페이스북',
#   '트위터',
#   '페리',
#   '스코프',
#   '트위치',
#   '코로나',
#   '사회',
#   '교회',
#   '예배',
#   '요한계시록',
#   '휴거',
#   '환란',
#   '회개',
#   '주님',
#   '예비',
#   '메시아'],
#  ['카페'],
#  ['예술', '그래픽디자이너', '일러스트', '일러스트레이터', '수채화', '꽃', '그림책', '코로나'],
#  ['요한계시록',
#   '선지자',
#   '금',
#   '예배',
#   '설교',
#   '통역',
#   '생중계',
#   '유튜브',
#   '페이스북',
#   '트위터',
#   '페리',
#   '스코프',
#   '트위치',
#   '코로나',
#   '사회',
#   '교회',
#   '예배',
#   '요한계시록',
#   '휴거',
#   '환란',
#   '회개',
#   '주님',
#   '예비',
#   '메시아'],
#  ['요한계시록',
#   '선지자',
#   '금',
#   '예배',
#   '설교',
#   '통역',
#   '생중계',
#   '유튜브',
#   '페이스북',
#   '트위터',
#   '페리',
#   '스코프',
#   '트위치',
#   '코로나',
#   '사회',
#   '교회',
#   '예배',
#   '요한계시록',
#   '휴거',
#   '환란',
#   '회개',
#   '주님',
#   '예비',
#   '메시아'],
#  ['요한계시록',
#   '선지자',
#   '금',
#   '예배',
#   '설교',
#   '통역',
#   '생중계',
#   '유튜브',
#   '페이스북',
#   '트위터',
#   '페리',
#   '스코프',
#   '트위치',
#   '코로나',
#   '사회',
#   '교회',
#   '예배',
#   '요한계시록',
#   '휴거',
#   '환란',
#   '회개',
#   '주님',
#   '예비',
#   '메시아'],
#  ['가슴',
#   '운동',
#   '헬',
#   '스타',
#   '헬스',
#   '운동',
#   '남자',
#   '운동',
#   '스타',
#   '다이어트',
#   '헬린',
#   '기록',
#   '스타',
#   '팔로',
#   '우미',
#   '보디빌딩',
#   '코로나'],
#  ['코로나',
#   '부탁',
#   '야구',
#   '운동선수',
#   '년생',
#   '팔로잉',
#   '디엠',
#   '디엠',
#   '스타',
#   '야구',
#   '스타',
#   '코로나',
#   '마스크',
#   '스타'],
#  ['요한계시록',
#   '선지자',
#   '금',
#   '예배',
#   '설교',
#   '통역',
#   '생중계',
#   '유튜브',
#   '페이스북',
#   '트위터',
#   '페리',
#   '스코프',
#   '트위치',
#   '코로나',
#   '사회',
#   '교회',
#   '예배',
#   '요한계시록',
#   '휴거',
#   '환란',
#   '회개',
#   '주님',
#   '예비',
#   '메시아'],
#  ['협찬', '닥터', '자외선', '살균', '기', '캠핑', '코로나', '위', '필수', '템', '초', '박멸', '입문'],
#  ['요한계시록',
#   '선지자',
#   '금',
#   '예배',
#   '설교',
#   '통역',
#   '생중계',
#   '유튜브',
#   '페이스북',
#   '트위터',
#   '페리',
#   '스코프',
#   '트위치',
#   '코로나',
#   '사회',
#   '교회',
#   '예배',
#   '요한계시록',
#   '휴거',
#   '환란',
#   '회개',
#   '주님',
#   '예비',
#   '메시아'],
#  ['회개',
#   '주님',
#   '예비',
#   '하나님',
#   '휴거',
#   '증인',
#   '천국',
#   '보좌',
#   '영광',
#   '오심',
#   '지구',
#   '신부',
#   '오심',
#   '죄',
#   '회개',
#   '로움',
#   '정',
#   '결함',
#   '코로나',
#   '재난',
#   '상공',
#   '박',
#   '일본',
#   '교회',
#   '부흥',
#   '골목',
#   '식당',
#   '정인',
#   '스포츠',
#   '기상청',
#   '이낙연',
#   '집사부',
#   '일체',
#   '현대',
#   '테슬라',
#   '미국'],
#  ['한주',
#   '마감',
#   '금요일',
#   '소식',
#   '마지막',
#   '문자',
#   '금요일',
#   '밤',
#   '코로나',
#   '왕자',
#   '바이엘',
#   '권',
#   '과정',
#   '스타트',
#   '행복',
#   '스타',
#   '쌤',
#   '스타',
#   '뮤직',
#   '피아노',
#   '레슨',
#   '구미',
#   '옥계',
#   '산동',
#   '석사',
#   '피아니스트',
#   '럽',
#   '스타'],
#  ['코로나',
#   '스콘',
#   '박',
#   '코로나',
#   '집콕',
#   '베이',
#   '킹',
#   '생크림',
#   '스콘',
#   '자신감',
#   '담번',
#   '모닝',
#   '빵'],
#  ['작가',
#   '재료',
#   '공부',
#   '전공',
#   '개발',
#   '업무',
#   '임',
#   '성빈',
#   '일요일',
#   '저녁',
#   '금요일',
#   '저녁',
#   '하디',
#   '직장인',
#   '중'],
#  ['머리', '립스틱', '통닭'],
#  ['오빠'],
#  ['생일', '간만', '생일', '코로나', '파티', '최고', '생일', '감동', '연속', '행복', '천안', '정동'],
#  ['엔빠', '내일', '오픈', '용'],
#  ['눈',
#   '탱탱',
#   '부엇구둔용',
#   '전신',
#   '샷',
#   '운동',
#   '훈녀',
#   '스타',
#   '디엠',
#   '아프리카',
#   '여름',
#   '코로나',
#   '훈녀',
#   '출근',
#   '아침',
#   '스타'],
#  ['보기', '코로나', '집콕', '맥주', '섭렵', '편의점', '맥주', '혼술', '혼맥', '술', '스타', '술'],
#  ['미용사',
#   '일반',
#   '헤어',
#   '자격증',
#   '취득',
#   '과정',
#   '개강',
#   '사회',
#   '코로나',
#   '단계',
#   '방역',
#   '손소독',
#   '발열',
#   '체크',
#   '마스크',
#   '방역',
#   '비상',
#   '대피훈련',
#   '완벽',
#   '안심',
#   '자격증',
#   '취득'],
#  ['치즈', '싸람'],
#  ['민화',
#   '어해',
#   '물감',
#   '색칠',
#   '청주',
#   '아동',
#   '미술',
#   '청주',
#   '아동',
#   '미술',
#   '학원',
#   '아동',
#   '미술',
#   '미술',
#   '미술',
#   '학원',
#   '코로나',
#   '마스크',
#   '착용',
#   '사회',
#   '초등',
#   '미술',
#   '민화',
#   '달력',
#   '민화',
#   '어해',
#   '물감',
#   '색칠',
#   '죽림초',
#   '죽림',
#   '미술',
#   '화초',
#   '성화동',
#   '미술',
#   '학원',
#   '청주',
#   '클림트',
#   '미술',
#   '학원'],
#  ['라인',
#   '나이',
#   '구애',
#   '코스프레',
#   '제복',
#   '직업',
#   '계통',
#   '중점',
#   '구합',
#   '니',
#   '염두',
#   '에이전시',
#   '수수료',
#   '요구',
#   '외모',
#   '타투',
#   '흉터',
#   '상관',
#   '아시',
#   '디엠',
#   '요기',
#   '본급',
#   '협의',
#   '스폰',
#   '스폰서',
#   '부업',
#   '대출',
#   '목돈',
#   '패션',
#   '대학생',
#   '고등학생',
#   '코디',
#   '뷰티',
#   '카페',
#   '코로나',
#   '알바',
#   '모델',
#   '페이',
#   '모델',
#   '학생',
#   '돌싱',
#   '육아',
#   '부업',
#   '코스프레',
#   '코스',
#   '간호사',
#   '스튜디어스',
#   '대출',
#   '승무원',
#   '간호사',
#   '필라테스',
#   '타투',
#   '헬스',
#   '트레이너'],
#  ['맛집', '맛스타', '먹방', '스타', '집', '곰탕', '김치', '집밥', '최고', '저녁', '코로나', '집콕'],
#  ['편맥', '편의점', '맥주', '개', '만원', '코로나', '얼음', '맥주', '알콜', '캔', '원샷', '병', '맥주'],
#  ['코로나', '중', '춥다'],
#  ['년전',
#   '호캉스',
#   '해도',
#   '마스크',
#   '마지막',
#   '건대',
#   '에이치',
#   '비뉴',
#   '호캉스',
#   '수풀',
#   '코로나',
#   '호',
#   '캉스',
#   '기분',
#   '전환'],
#  ['기부',
#   '코로나',
#   '주눅',
#   '방역',
#   '칙',
#   '화이팅',
#   '렛츠위크',
#   '렛츠위크',
#   '걸음',
#   '기부',
#   '아모레퍼시픽',
#   '아모레',
#   '걸음걸이',
#   '코로나',
#   '코로나',
#   '코로나'],
#  ['분위기',
#   '까페',
#   '고깃집',
#   '도깨비',
#   '집',
#   '코로나',
#   '정부',
#   '지침',
#   '준수',
#   '인',
#   '이하',
#   '속',
#   '이틀',
#   '연속',
#   '만석',
#   '사랑',
#   '최선',
#   '다해',
#   '진심',
#   '도깨비',
#   '집',
#   '창원',
#   '맛집',
#   '상남동',
#   '맛집',
#   '배달',
#   '민족',
#   '맛집',
#   '삼겹살',
#   '맛집',
#   '우삼겹',
#   '대패',
#   '삼겹',
#   '점심',
#   '특선',
#   '낮술',
#   '자영',
#   '업자',
#   '코로나'],
#  ['공주',
#   '코닥',
#   '코닥',
#   '패럴',
#   '퇴근',
#   '금요일',
#   '이쁜이',
#   '코로나',
#   '스타',
#   '스타',
#   '옷',
#   '스트릿',
#   '옷',
#   '스타',
#   '전신',
#   '샷',
#   '안산',
#   '중앙'],
#  ['사계절',
#   '파자마',
#   '오픈',
#   '만원',
#   '초반',
#   '달',
#   '진행',
#   '사계절',
#   '내내',
#   '하트',
#   '네이비',
#   '체크',
#   '핑크',
#   '체크',
#   '노랑',
#   '체크',
#   '화이트',
#   '트',
#   '블랙',
#   '트',
#   '핑크',
#   '트',
#   '상의',
#   '기장',
#   '가슴',
#   '둘레',
#   '어깨',
#   '소매',
#   '바지',
#   '길이',
#   '상의',
#   '기장',
#   '가슴',
#   '둘레',
#   '어깨',
#   '소매',
#   '바지',
#   '길이',
#   '상의',
#   '기장',
#   '가슴',
#   '둘레',
#   '어깨',
#   '소매',
#   '바지',
#   '길이',
#   '상의',
#   '기장',
#   '가슴',
#   '둘레',
#   '어깨',
#   '소매',
#   '바지',
#   '길이',
#   '오차'],
#  ['뻥튀기', '공작', '부모님', '가게', '가격', '관고동', '애용', '인', '금지', '중', '염병', '코로나'],
#  ['에밀리', '집콕', '랜선', '여행', '댱', '어어', '힝', '마스크', '요', '랜선', '여행'],
#  ['코로나',
#   '방역',
#   '칙',
#   '사교육',
#   '연습',
#   '제대로',
#   '연습',
#   '주말',
#   '샴푸',
#   '근대',
#   '거',
#   '쫌잇음',
#   '화낼',
#   '본인',
#   '격어봣',
#   '인정',
#   '밥',
#   '화장실',
#   '제대로',
#   '욕',
#   '해주',
#   '위치',
#   '화이팅'],
#  ['날씨',
#   '야구',
#   '날씨',
#   '운동선수',
#   '년생',
#   '디엠',
#   '디엠',
#   '스타',
#   '야구',
#   '스타',
#   '코로나',
#   '마스크',
#   '필수',
#   '템'],
#  ['사계절',
#   '파자마',
#   '오픈',
#   '상품',
#   '만원',
#   '초반',
#   '달',
#   '진행',
#   '사계절',
#   '내내',
#   '하트',
#   '네이비',
#   '체크',
#   '핑크',
#   '체크',
#   '노랑',
#   '체크',
#   '화이트',
#   '트',
#   '블랙',
#   '트',
#   '핑크',
#   '트',
#   '상의',
#   '기장',
#   '가슴',
#   '둘레',
#   '어깨',
#   '소매',
#   '바지',
#   '길이',
#   '상의',
#   '기장',
#   '가슴',
#   '둘레',
#   '어깨',
#   '소매',
#   '바지',
#   '길이',
#   '상의',
#   '기장',
#   '가슴',
#   '둘레',
#   '어깨',
#   '소매',
#   '바지',
#   '길이',
#   '상의',
#   '기장',
#   '가슴',
#   '둘레',
#   '어깨',
#   '소매',
#   '바지',
#   '길이',
#   '오차'],
#  ['원래', '겨울', '계절', '얼굴', '리'],
#  ['리테일',
#   '수단',
#   '매도',
#   '단가',
#   '실현',
#   '손익',
#   '약',
#   '목표',
#   '약',
#   '단기',
#   '중기',
#   '리테일',
#   '편의점',
#   '사업',
#   '영위',
#   '이후',
#   '장기',
#   '박스',
#   '움직',
#   '현재',
#   '평가',
#   '구간',
#   '매수',
#   '영업',
#   '이익',
#   '매출',
#   '액',
#   '증가',
#   '상품',
#   '개발',
#   '통해',
#   '기업',
#   '고유',
#   '정체',
#   '부각',
#   '실적',
#   '증가',
#   '매수',
#   '편의점',
#   '리테일',
#   '박스',
#   '바닥'],
#  [],
#  ['격리',
#   '일기',
#   '금',
#   '격리',
#   '생활관',
#   '세탁기',
#   '건조대',
#   '빨래',
#   '에이',
#   '뭐',
#   '그냥',
#   '볼',
#   '건',
#   '격리',
#   '해제',
#   '세탁기',
#   '옷',
#   '속옷',
#   '수건',
#   '양말',
#   '이불',
#   '베개',
#   '인스타',
#   '툰',
#   '일러스트',
#   '웹툰',
#   '빨래',
#   '아이패드',
#   '아이패드',
#   '그림',
#   '코로나',
#   '자가',
#   '격리'],
#  ['가나',
#   '광',
#   '철철',
#   '설명',
#   '절',
#   '선물',
#   '미리',
#   '얼굴',
#   '인셀덤',
#   '두피',
#   '보',
#   '랩',
#   '바디',
#   '슈아멜',
#   '엑티브',
#   '클린',
#   '업',
#   '파우더',
#   '안제',
#   '거품',
#   '팩',
#   '발라',
#   '오일',
#   '미스트',
#   '피부',
#   '장벽',
#   '강화',
#   '카밍',
#   '밸런스',
#   '젤',
#   '수분',
#   '보습',
#   '젤',
#   '톨로',
#   '퍼스트',
#   '패키지',
#   '부스터',
#   '럼',
#   '엑티브',
#   '크림',
#   '볼륨',
#   '보습',
#   '크림',
#   '팩',
#   '칵테일',
#   '아쿠아',
#   '젤',
#   '진정',
#   '쿨링',
#   '자외선',
#   '차단',
#   '칵테일',
#   '아쿠아',
#   '비비',
#   '톤업',
#   '유리',
#   '알',
#   '비비',
#   '러스터',
#   '쿠션',
#   '블루',
#   '라이트',
#   '차단',
#   '꿀광',
#   '쿠션',
#   '보',
#   '랩',
#   '헤어',
#   '케어',
#   '세트',
#   '탈모',
#   '완화',
#   '모근',
#   '두피',
#   '건강',
#   '슈아멜',
#   '바디',
#   '케어',
#   '세트',
#   '영양',
#   '보습',
#   '탄력',
#   '강화',
#   '리만',
#   '코리아',
#   '발라',
#   '본부',
#   '그룹',
#   '인셀덤',
#   '사업',
#   '디엠',
#   '오픈',
#   '카톡',
#   '뷰티',
#   '창업',
#   '울산',
#   '퀵',
#   '배송',
#   '전국',
#   '배송',
#   '나영',
#   '토탈',
#   '뷰티',
#   '피부',
#   '타입',
#   '루틴',
#   '케어',
#   '비지니스',
#   '매니저',
#   '파워',
#   '매니저',
#   '직급',
#   '전국',
#   '후원',
#   '미팅',
#   '보상',
#   '플랜',
#   '미팅',
#   '팀',
#   '미팅',
#   '피부',
#   '교육',
#   '비지니스',
#   '교육',
#   '울산',
#   '셀덤',
#   '인셀덤더',
#   '나영',
#   '발라',
#   '본부',
#   '인셀덤',
#   '그룹'],
#  ['느낌',
#   '터키',
#   '마스크',
#   '코로나',
#   '공감',
#   '여행',
#   '스타',
#   '여행',
#   '스타',
#   '여행',
#   '풍경',
#   '추억',
#   '카메라',
#   '감성',
#   '색감',
#   '색감',
#   '보정'],
#  ['환절기',
#   '손씻기',
#   '강조',
#   '코로나',
#   '외출',
#   '집',
#   '자주',
#   '편이',
#   '변기',
#   '자극',
#   '경고',
#   '충격',
#   '청결',
#   '건강',
#   '자주',
#   '알코올',
#   '합성',
#   '계면활성제',
#   '정제',
#   '민감',
#   '건성',
#   '습진',
#   '아토피',
#   '피부',
#   '자극',
#   '보습',
#   '성분',
#   '정제',
#   '핸드',
#   '크림',
#   '잔뜩',
#   '발라',
#   '본질',
#   '문제',
#   '개선',
#   '인위',
#   '성분',
#   '이유',
#   '성분',
#   '채운',
#   '어스',
#   '후드',
#   '손세정제',
#   '주방',
#   '세제',
#   '무려',
#   '농축',
#   '비누',
#   '청정',
#   '지역',
#   '아이슬란드',
#   '이끼',
#   '추출',
#   '물',
#   '보습',
#   '북유럽',
#   '아이슬란드',
#   '이끼',
#   '가루',
#   '식용',
#   '약재',
#   '재료',
#   '자연',
#   '성분',
#   '만큼',
#   '거품',
#   '타입',
#   '정제',
#   '어스',
#   '후드',
#   '액',
#   '타입',
#   '쓰기',
#   '쓰기',
#   '성분',
#   '보고',
#   '고민',
#   '거품',
#   '용기',
#   '초',
#   '간단',
#   '나름',
#   '팁',
#   '어스',
#   '후드',
#   '농축',
#   '액',
#   '쓰시',
#   '물',
#   '세제',
#   '비율',
#   '정도',
#   '영상',
#   '봐쥬세오',
#   '해',
#   '거품',
#   '용기',
#   '시중',
#   '거품',
#   '타입',
#   '손세정제',
#   '난',
#   '비누',
#   '향',
#   '느낌',
#   '느낌',
#   '느낌',
#   '자주',
#   '정착',
#   '템',
#   '요'],
#  ['접촉', '체온계', '기사', '약국', '피버', '약국', '체온계', '관심'],
#  ['에이',
#   '블짐',
#   '중계',
#   '코로나',
#   '운동',
#   '항상',
#   '환기',
#   '방역',
#   '소독',
#   '실시',
#   '퐈이팅입',
#   '에이',
#   '블짐',
#   '에이',
#   '블짐',
#   '중계',
#   '운동',
#   '맛집',
#   '운동',
#   '남자',
#   '운동',
#   '다이어트',
#   '터',
#   '중계',
#   '헬스',
#   '중계',
#   '하계헬스',
#   '계',
#   '방역',
#   '소독',
#   '코로나'],
#  ['화면',
#   '재생',
#   '은혜',
#   '아래',
#   '모든',
#   '죄',
#   '해방',
#   '사랑',
#   '안',
#   '스티',
#   '은혜',
#   '아래',
#   '사랑',
#   '안',
#   '금요일',
#   '겨울',
#   '밤',
#   '밤하늘',
#   '코로나',
#   '감기',
#   '찬양',
#   '씨씨엠',
#   '갓스펠',
#   '음악',
#   '스타',
#   '뮤직스타'],
#  ['광주',
#   '공원',
#   '포차',
#   '아방궁',
#   '광주',
#   '공원',
#   '포차',
#   '아방궁',
#   '닭발',
#   '돌뼈',
#   '광주',
#   '공원',
#   '포차',
#   '코로나',
#   '못',
#   '배달',
#   '민족',
#   '분위기',
#   '맛스타',
#   '맛저',
#   '스타',
#   '스타',
#   '스타',
#   '야식',
#   '야식',
#   '스타',
#   '배달',
#   '음식',
#   '배달',
#   '맛집',
#   '뭐',
#   '배달',
#   '음식',
#   '소주',
#   '맥주',
#   '소맥',
#   '굿'],
#  [],
#  ['역시',
#   '라이',
#   '진짜',
#   '시술',
#   '가야',
#   '김민주',
#   '젊음',
#   '탱탱',
#   '볼',
#   '시술',
#   '답',
#   '민주',
#   '코로나',
#   '집밖',
#   '뭐',
#   '놀수',
#   '이사',
#   '정처'],
#  ['실패', '곳', '생일', '축하', '해'],
#  [],
#  ['경기도',
#   '긴급',
#   '브리핑',
#   '절박',
#   '도민',
#   '어려움',
#   '외면',
#   '경기도',
#   '나이',
#   '직업',
#   '소득',
#   '모든',
#   '도민',
#   '만원',
#   '경기도',
#   '재난',
#   '기본소득',
#   '지급',
#   '지급',
#   '금액',
#   '만원',
#   '지급',
#   '대상',
#   '경기도',
#   '주소',
#   '경기',
#   '도민',
#   '지급',
#   '방식',
#   '경기',
#   '지역화폐',
#   '카드',
#   '신용카드',
#   '소멸성',
#   '지역화폐',
#   '지급',
#   '신청',
#   '시기',
#   '코로나',
#   '방역',
#   '상황',
#   '고려',
#   '추후',
#   '공지',
#   '보도자료',
#   '보기',
#   '구리',
#   '신용카드',
#   '원금',
#   '재난',
#   '원금',
#   '코로나',
#   '재난',
#   '원금',
#   '경기도',
#   '구리',
#   '다비치',
#   '안경',
#   '다비치',
#   '구리',
#   '구리',
#   '안경'],
#  ['화면',
#   '재생',
#   '영화',
#   '수도',
#   '이름',
#   '어딘가',
#   '릴',
#   '보이',
#   '엔딩',
#   '이름',
#   '기억',
#   '금요일',
#   '겨울',
#   '밤',
#   '밤하늘',
#   '코로나',
#   '감기',
#   '음악',
#   '노래',
#   '음',
#   '스타',
#   '음악',
#   '스타',
#   '뮤직스타'],
#  ['예전',
#   '멀리',
#   '고등학교',
#   '진학',
#   '주위',
#   '선배',
#   '게',
#   '기억',
#   '무작정',
#   '학교',
#   '발',
#   '학교',
#   '선배',
#   '통해',
#   '정보',
#   '미리',
#   '모습',
#   '고민',
#   '도움',
#   '글',
#   '도움',
#   '서로',
#   '으샷으샷'],
#  ['코로나', '집콕', '조심', '디저트', '카페', '카페', '코로나', '분위기'],
#  ['곰탕', '코로나', '땜시', '집밥', '요리'],
#  ['월곡',
#   '동덕여대',
#   '피부관리',
#   '마스크',
#   '속',
#   '피부',
#   '상태',
#   '여드름',
#   '주의',
#   '방치',
#   '답',
#   '마감',
#   '마감',
#   '마감',
#   '마감',
#   '오전',
#   '타임',
#   '마감',
#   '미리',
#   '미리',
#   '부탁',
#   '모든',
#   '손님',
#   '손씻기',
#   '손세정제',
#   '배드',
#   '소독',
#   '사전',
#   '제로',
#   '당일',
#   '케어',
#   '앤',
#   '큐어',
#   '월곡동',
#   '월곡역',
#   '피부관리',
#   '동덕여대',
#   '피부관리',
#   '피부관리',
#   '월곡',
#   '피부관리',
#   '동덕여대',
#   '피부관리',
#   '성북구',
#   '피부관리',
#   '피부관리',
#   '곳',
#   '여드름',
#   '효과',
#   '압',
#   '곳',
#   '후기',
#   '증명',
#   '겨울',
#   '겨울',
#   '필수',
#   '진정',
#   '마스크',
#   '코로나',
#   '블랙',
#   '필',
#   '호박',
#   '필'],
#  ['스타', '학생', '스타', '스타', '중', '스타', '왜케', '학생', '중딩', '년생', '코로나'],
#  ['펀',
#   '플렉스',
#   '금요일',
#   '마무리',
#   '펀',
#   '플렉스',
#   '괌',
#   '본사',
#   '가맹',
#   '키카',
#   '톡',
#   '울산',
#   '센터',
#   '대표',
#   '번호',
#   '울산',
#   '원장',
#   '직통',
#   '전화',
#   '울산',
#   '축구',
#   '클럽',
#   '감독',
#   '직통',
#   '전화',
#   '양산',
#   '원장',
#   '직통',
#   '전화',
#   '울산',
#   '펀',
#   '플렉스',
#   '괌',
#   '여행',
#   '울산',
#   '유아',
#   '체육',
#   '울산',
#   '유아',
#   '축구',
#   '괌',
#   '가족',
#   '여행',
#   '괌',
#   '달',
#   '살기',
#   '유아',
#   '체육',
#   '산아이',
#   '곳',
#   '울산',
#   '핫',
#   '괌',
#   '캠프',
#   '괌펀',
#   '플렉스',
#   '펀플렉스괌',
#   '산유',
#   '소년',
#   '축구',
#   '클럽',
#   '울산',
#   '괌',
#   '모닝',
#   '펀',
#   '플렉스',
#   '코로나',
#   '울산',
#   '페이'],
#  ['햇살', '맛집'],
#  ['걸프',
#   '존',
#   '남성',
#   '보이스',
#   '캐디',
#   '목소리',
#   '제공',
#   '김기성',
#   '프로',
#   '부산',
#   '서울',
#   '해운대',
#   '서면',
#   '광안',
#   '리',
#   '골프',
#   '부산',
#   '골프',
#   '부산',
#   '골프',
#   '프로',
#   '부산',
#   '골프',
#   '레슨',
#   '부산',
#   '골프',
#   '모임',
#   '해운대',
#   '골프',
#   '이승우',
#   '프로',
#   '사이다',
#   '스윙',
#   '오버',
#   '협찬',
#   '골프',
#   '웨어',
#   '코로나',
#   '시대',
#   '극복'],
#  ['젠', '커피', '기', '코로나', '카페', '커피'],
#  ['심정'],
#  ['기록',
#   '코로나',
#   '코로나',
#   '검사',
#   '어쩌다가',
#   '코로나',
#   '검사',
#   '유증',
#   '검사',
#   '쫄',
#   '순서',
#   '앞',
#   '검사',
#   '왕왕',
#   '순간',
#   '쫄렸',
#   '심정',
#   '눈물',
#   '다행',
#   '정말',
#   '가까이',
#   '방호복',
#   '사람',
#   '보',
#   '심리',
#   '정말',
#   '위축',
#   '사람',
#   '일일이',
#   '응대',
#   '대답',
#   '정말',
#   '결과',
#   '음성',
#   '안'],
#  ['동호회', '팀', '서로', '기본', '예의', '킹콩', '샤워', '남양주', '코로나'],
#  ['싱'],
#  ['꼬마', '모바일', '방송', '사업'],
#  ['파티', '별', '방역', '소독', '코로나', '방역', '현수막', '파티', '용품', '소독', '의전'],
#  ['스테이크'],
#  ['장어',
#   '별로',
#   '돌돔',
#   '순천',
#   '장어구이',
#   '장어',
#   '금',
#   '마파도',
#   '돌돔',
#   '형',
#   '형집',
#   '로얄',
#   '샬',
#   '루트',
#   '맛집',
#   '석식',
#   '잔고',
#   '재',
#   '충전',
#   '이군',
#   '공사',
#   '토지',
#   '폭등',
#   '코로나'],
#  ['금요일',
#   '치즈',
#   '떡볶이',
#   '순대',
#   '튀김',
#   '분식',
#   '퀄리티',
#   '셋팅',
#   '느낌',
#   '카스',
#   '병',
#   '맥주',
#   '박스',
#   '정도',
#   '코로나',
#   '땜시',
#   '방',
#   '구석'],
#  ['펀',
#   '플렉스',
#   '진짜',
#   '금요일',
#   '펀',
#   '플렉스',
#   '괌',
#   '본사',
#   '가맹',
#   '키카',
#   '톡',
#   '울산',
#   '센터',
#   '대표',
#   '번호',
#   '울산',
#   '원장',
#   '직통',
#   '전화',
#   '울산',
#   '축구',
#   '클럽',
#   '감독',
#   '직통',
#   '전화',
#   '양산',
#   '원장',
#   '직통',
#   '전화',
#   '울산',
#   '펀',
#   '플렉스',
#   '괌',
#   '여행',
#   '울산',
#   '유아',
#   '체육',
#   '울산',
#   '유아',
#   '축구',
#   '괌',
#   '가족',
#   '여행',
#   '괌',
#   '달',
#   '살기',
#   '유아',
#   '체육',
#   '산아이',
#   '곳',
#   '울산',
#   '핫',
#   '괌',
#   '캠프',
#   '괌펀',
#   '플렉스',
#   '펀플렉스괌',
#   '산유',
#   '소년',
#   '축구',
#   '클럽',
#   '울산',
#   '괌',
#   '모닝',
#   '펀',
#   '플렉스',
#   '코로나',
#   '울산',
#   '페이'],
#  ['신통',
#   '젠',
#   '한겨울',
#   '날씨',
#   '한결',
#   '날씨',
#   '건강',
#   '코로나',
#   '마스크',
#   '손님',
#   '맞이',
#   '기도',
#   '손님',
#   '응원',
#   '신통',
#   '치킨',
#   '예전',
#   '항상',
#   '응원',
#   '손님',
#   '맛',
#   '서비스',
#   '보답',
#   '홀',
#   '손님',
#   '포장',
#   '단체',
#   '포장',
#   '홍보',
#   '대구광역시',
#   '수성구',
#   '수성',
#   '대구',
#   '맛집',
#   '대구',
#   '코로나',
#   '치킨',
#   '치킨',
#   '치킨',
#   '맛집',
#   '맛집',
#   '맛집',
#   '맛집',
#   '스타',
#   '수성구',
#   '맛집',
#   '포장',
#   '술',
#   '스타',
#   '술',
#   '신통',
#   '치킨',
#   '신통',
#   '치킨'],
#  ['인천',
#   '부평역',
#   '증명사진',
#   '전문',
#   '이력서',
#   '취업',
#   '취준생',
#   '코로나',
#   '짜증',
#   '선',
#   '언팔',
#   '금지',
#   '디엠'],
#  ['베이스',
#   '모델',
#   '미니',
#   '안경',
#   '안경',
#   '라스트',
#   '안경',
#   '라스트',
#   '진주',
#   '베이스',
#   '온',
#   '홍대',
#   '패션',
#   '코디',
#   '뷰티',
#   '네일',
#   '서울',
#   '부산',
#   '대전',
#   '대구',
#   '울산',
#   '청주',
#   '광주',
#   '포항',
#   '목포',
#   '분당',
#   '일산',
#   '마산',
#   '순천',
#   '코로나'],
#  ['남친',
#   '남친',
#   '럽',
#   '스타',
#   '럽',
#   '스타',
#   '연애',
#   '카페',
#   '흑백',
#   '사랑',
#   '인스타',
#   '남편',
#   '코로나',
#   '감성',
#   '협찬',
#   '커플'],
#  ['조감도',
#   '글',
#   '글귀',
#   '글',
#   '스타',
#   '현실',
#   '세상',
#   '사회',
#   '인생',
#   '성찰',
#   '고찰',
#   '글쓰기',
#   '쓰기',
#   '사회',
#   '비판',
#   '서민',
#   '주식',
#   '교회',
#   '코로나',
#   '대유행',
#   '집콕',
#   '붕괴'],
#  [],
#  ['포인트',
#   '목걸이',
#   '자켓',
#   '코디',
#   '대구',
#   '부산여행',
#   '스타',
#   '훈녀',
#   '엘리자',
#   '벳펌',
#   '코로나',
#   '협찬',
#   '맛스타',
#   '가요',
#   '목걸이',
#   '선물'],
#  ['터닝',
#   '포인트',
#   '짐',
#   '연수',
#   '횐님',
#   '프레',
#   '젠또',
#   '오시',
#   '빵',
#   '보따리',
#   '수고',
#   '닷',
#   '횐님',
#   '항상',
#   '횐님들',
#   '관심',
#   '사랑',
#   '연수',
#   '직원',
#   '항상',
#   '불끈불끈',
#   '덕분',
#   '마음',
#   '자세',
#   '하루',
#   '헬스',
#   '골프',
#   '기구',
#   '필라테스',
#   '요가',
#   '스피닝',
#   '댄스',
#   '좌',
#   '연수',
#   '구월',
#   '예술회관역',
#   '터닝',
#   '포인트',
#   '짐',
#   '터닝',
#   '포인트',
#   '짐',
#   '좌점',
#   '터닝',
#   '포인트',
#   '짐',
#   '연수',
#   '터닝',
#   '포인트',
#   '짐',
#   '구월',
#   '터닝',
#   '포인트',
#   '짐',
#   '구월',
#   '예술회관역',
#   '가좌동',
#   '헬스장',
#   '연수동',
#   '헬스장',
#   '구월동',
#   '헬스장',
#   '가좌동',
#   '연수동',
#   '구월동',
#   '가좌동',
#   '헬스',
#   '연수동',
#   '헬스',
#   '구월동',
#   '헬스',
#   '젝',
#   '믹스',
#   '샵',
#   '필라테스',
#   '프사',
#   '즐거움',
#   '다이어트',
#   '홈',
#   '트레이닝',
#   '코로나',
#   '바디',
#   '프로필',
#   '헬스'],
#  ['메리츠화재', '실비', '보험', '보험료', '인부', '캠페인', '분석', '희망'],
#  ['터닝',
#   '포인트',
#   '짐',
#   '연수',
#   '횐님',
#   '프레',
#   '젠또',
#   '오시',
#   '빵',
#   '보따리',
#   '수고',
#   '닷',
#   '횐님',
#   '항상',
#   '횐님들',
#   '관심',
#   '사랑',
#   '연수',
#   '직원',
#   '항상',
#   '불끈불끈',
#   '덕분',
#   '마음',
#   '자세',
#   '하루',
#   '헬스',
#   '골프',
#   '기구',
#   '필라테스',
#   '요가',
#   '스피닝',
#   '댄스',
#   '좌',
#   '연수',
#   '구월',
#   '예술회관역',
#   '터닝',
#   '포인트',
#   '짐',
#   '터닝',
#   '포인트',
#   '짐',
#   '좌점',
#   '터닝',
#   '포인트',
#   '짐',
#   '연수',
#   '터닝',
#   '포인트',
#   '짐',
#   '구월',
#   '터닝',
#   '포인트',
#   '짐',
#   '구월',
#   '예술회관역',
#   '가좌동',
#   '헬스장',
#   '연수동',
#   '헬스장',
#   '구월동',
#   '헬스장',
#   '가좌동',
#   '연수동',
#   '구월동',
#   '가좌동',
#   '헬스',
#   '연수동',
#   '헬스',
#   '구월동',
#   '헬스',
#   '젝',
#   '믹스',
#   '샵',
#   '필라테스',
#   '프사',
#   '즐거움',
#   '다이어트',
#   '홈',
#   '트레이닝',
#   '코로나',
#   '바디',
#   '프로필',
#   '헬스'],
#  ['오일',
#   '파스텔',
#   '예술',
#   '혼',
#   '불',
#   '코로나',
#   '집콕',
#   '유',
#   '튜버',
#   '파리',
#   '노을',
#   '취미',
#   '부자',
#   '작품',
#   '확행'],
#  ['번가',
#   '코로나',
#   '매장',
#   '이용',
#   '하이네켄',
#   '제작',
#   '지원',
#   '물품',
#   '좀더',
#   '매장',
#   '방역',
#   '실시',
#   '장내',
#   '모든',
#   '고리',
#   '향균',
#   '방역',
#   '필름',
#   '부착',
#   '매장',
#   '곳',
#   '향균',
#   '터치',
#   '스티커',
#   '설치',
#   '방문',
#   '모든',
#   '마스크',
#   '보관',
#   '용',
#   '봉투',
#   '일회용',
#   '손세정제',
#   '지급',
#   '하이네켄',
#   '캔',
#   '편의점',
#   '가격',
#   '만원',
#   '배달',
#   '전용',
#   '잔',
#   '지급',
#   '생맥주',
#   '키트',
#   '예정',
#   '배달',
#   '민족',
#   '번가',
#   '번가',
#   '하이네켄',
#   '코로나',
#   '당진',
#   '맛집',
#   '신평',
#   '맛집',
#   '당진',
#   '술집',
#   '신평',
#   '술집',
#   '세한대'],
#  ['펀',
#   '플렉스',
#   '정말',
#   '귀염둥이',
#   '펀',
#   '플렉스',
#   '괌',
#   '본사',
#   '가맹',
#   '키카',
#   '톡',
#   '울산',
#   '센터',
#   '대표',
#   '번호',
#   '울산',
#   '원장',
#   '직통',
#   '전화',
#   '울산',
#   '축구',
#   '클럽',
#   '감독',
#   '직통',
#   '전화',
#   '양산',
#   '원장',
#   '직통',
#   '전화',
#   '울산',
#   '펀',
#   '플렉스',
#   '괌',
#   '여행',
#   '울산',
#   '유아',
#   '체육',
#   '울산',
#   '유아',
#   '축구',
#   '괌',
#   '가족',
#   '여행',
#   '괌',
#   '달',
#   '살기',
#   '유아',
#   '체육',
#   '산아이',
#   '곳',
#   '울산',
#   '핫',
#   '괌',
#   '캠프',
#   '괌펀',
#   '플렉스',
#   '펀플렉스괌',
#   '산유',
#   '소년',
#   '축구',
#   '클럽',
#   '울산',
#   '괌',
#   '모닝',
#   '펀',
#   '플렉스',
#   '코로나',
#   '울산',
#   '페이'],
#  ['터닝',
#   '포인트',
#   '짐',
#   '연수',
#   '횐님',
#   '프레',
#   '젠또',
#   '오시',
#   '빵',
#   '보따리',
#   '수고',
#   '닷',
#   '횐님',
#   '항상',
#   '횐님들',
#   '관심',
#   '사랑',
#   '연수',
#   '직원',
#   '항상',
#   '불끈불끈',
#   '덕분',
#   '마음',
#   '자세',
#   '하루',
#   '헬스',
#   '골프',
#   '기구',
#   '필라테스',
#   '요가',
#   '스피닝',
#   '댄스',
#   '좌',
#   '연수',
#   '구월',
#   '예술회관역',
#   '터닝',
#   '포인트',
#   '짐',
#   '터닝',
#   '포인트',
#   '짐',
#   '좌점',
#   '터닝',
#   '포인트',
#   '짐',
#   '연수',
#   '터닝',
#   '포인트',
#   '짐',
#   '구월',
#   '터닝',
#   '포인트',
#   '짐',
#   '구월',
#   '예술회관역',
#   '가좌동',
#   '헬스장',
#   '연수동',
#   '헬스장',
#   '구월동',
#   '헬스장',
#   '가좌동',
#   '연수동',
#   '구월동',
#   '가좌동',
#   '헬스',
#   '연수동',
#   '헬스',
#   '구월동',
#   '헬스',
#   '젝',
#   '믹스',
#   '샵',
#   '필라테스',
#   '프사',
#   '즐거움',
#   '다이어트',
#   '홈',
#   '트레이닝',
#   '코로나',
#   '바디',
#   '프로필',
#   '헬스'],
#  ['재',
#   '키스',
#   '피닝',
#   '통영',
#   '죽림스피닝',
#   '죽림',
#   '스피닝',
#   '즉림',
#   '에버그린',
#   '빌딩',
#   '층',
#   '죽림',
#   '유일',
#   '재키',
#   '페',
#   '밀리',
#   '클럽',
#   '코로나',
#   '코로나',
#   '소독',
#   '환기',
#   '코로나',
#   '인원',
#   '제한',
#   '시간제',
#   '재키',
#   '홀릭',
#   '예비',
#   '마스터',
#   '통영',
#   '공연',
#   '통영',
#   '요가',
#   '통영',
#   '필라테스',
#   '통영',
#   '스트레칭',
#   '통영',
#   '다이어트',
#   '통영',
#   '운동'],
#  ['제목',
#   '탈',
#   '룰라',
#   '항연',
#   '곽',
#   '일병',
#   '역시',
#   '명일',
#   '여행',
#   '양평',
#   '아바타',
#   '펜션',
#   '코로나',
#   '인',
#   '집합',
#   '금지',
#   '내년'],
#  ['터닝',
#   '포인트',
#   '짐',
#   '연수',
#   '횐님',
#   '프레',
#   '젠또',
#   '오시',
#   '빵',
#   '보따리',
#   '수고',
#   '닷',
#   '횐님',
#   '항상',
#   '횐님들',
#   '관심',
#   '사랑',
#   '연수',
#   '직원',
#   '항상',
#   '불끈불끈',
#   '덕분',
#   '마음',
#   '자세',
#   '하루',
#   '헬스',
#   '골프',
#   '기구',
#   '필라테스',
#   '요가',
#   '스피닝',
#   '댄스',
#   '좌',
#   '연수',
#   '구월',
#   '예술회관역',
#   '터닝',
#   '포인트',
#   '짐',
#   '터닝',
#   '포인트',
#   '짐',
#   '좌점',
#   '터닝',
#   '포인트',
#   '짐',
#   '연수',
#   '터닝',
#   '포인트',
#   '짐',
#   '구월',
#   '터닝',
#   '포인트',
#   '짐',
#   '구월',
#   '예술회관역',
#   '가좌동',
#   '헬스장',
#   '연수동',
#   '헬스장',
#   '구월동',
#   '헬스장',
#   '가좌동',
#   '연수동',
#   '구월동',
#   '가좌동',
#   '헬스',
#   '연수동',
#   '헬스',
#   '구월동',
#   '헬스',
#   '젝',
#   '믹스',
#   '샵',
#   '필라테스',
#   '프사',
#   '즐거움',
#   '다이어트',
#   '홈',
#   '트레이닝',
#   '코로나',
#   '바디',
#   '프로필',
#   '헬스'],
#  ['유니크',
#   '스페셜',
#   '레트로',
#   '연예인',
#   '여행',
#   '캐리어',
#   '그동안',
#   '수고',
#   '코로나',
#   '마음껏',
#   '사랑',
#   '사람',
#   '여행',
#   '그동안',
#   '여행',
#   '캐리어',
#   '검색',
#   '생활',
#   '필',
#   '요한',
#   '건',
#   '질',
#   '상품',
#   '합리',
#   '할인',
#   '가격',
#   '해외',
#   '대행',
#   '쇼핑',
#   '전문',
#   '여행',
#   '캐리어',
#   '여행',
#   '캐리어',
#   '여행',
#   '용',
#   '캐리어',
#   '유니크',
#   '레트로',
#   '예술',
#   '스페셜',
#   '캐리어',
#   '연예인',
#   '캐리어',
#   '여행',
#   '용품',
#   '여행',
#   '용',
#   '캐리어',
#   '내용',
#   '네이버',
#   '스마트',
#   '스토어',
#   '스토어',
#   '검색',
#   '해외',
#   '대행',
#   '해외',
#   '대행',
#   '쇼핑몰',
#   '코로나',
#   '코로나',
#   '종식',
#   '여행',
#   '자유',
#   '국내',
#   '여행',
#   '해외여행'],
#  ['툰', '진짜진짜', '할아버지', '정말', '뭐'],
#  ['바이든',
#   '대통령',
#   '나라',
#   '미국',
#   '여행',
#   '모든',
#   '사람',
#   '항공기',
#   '출발',
#   '검사',
#   '필요',
#   '미국',
#   '도착',
#   '격리',
#   '필요',
#   '말',
#   '미국',
#   '입국',
#   '격리',
#   '요구',
#   '권고',
#   '사항',
#   '실제',
#   '명령',
#   '발효',
#   '대해',
#   '귀',
#   '출처',
#   '매일경제',
#   '신문'],
#  ['눈물',
#   '컨',
#   '페티',
#   '개',
#   '스타',
#   '템',
#   '다이어리',
#   '다이어리',
#   '다이어리',
#   '제본',
#   '노트',
#   '스티커',
#   '취미',
#   '취미',
#   '생활',
#   '집콕',
#   '코로나',
#   '휴식'],
#  ['터닝',
#   '포인트',
#   '짐',
#   '연수',
#   '횐님',
#   '프레',
#   '젠또',
#   '오시',
#   '빵',
#   '보따리',
#   '수고',
#   '닷',
#   '횐님',
#   '항상',
#   '횐님들',
#   '관심',
#   '사랑',
#   '연수',
#   '직원',
#   '항상',
#   '불끈불끈',
#   '덕분',
#   '마음',
#   '자세',
#   '하루',
#   '헬스',
#   '골프',
#   '기구',
#   '필라테스',
#   '요가',
#   '스피닝',
#   '댄스',
#   '좌',
#   '연수',
#   '구월',
#   '예술회관역',
#   '터닝',
#   '포인트',
#   '짐',
#   '터닝',
#   '포인트',
#   '짐',
#   '좌점',
#   '터닝',
#   '포인트',
#   '짐',
#   '연수',
#   '터닝',
#   '포인트',
#   '짐',
#   '구월',
#   '터닝',
#   '포인트',
#   '짐',
#   '구월',
#   '예술회관역',
#   '가좌동',
#   '헬스장',
#   '연수동',
#   '헬스장',
#   '구월동',
#   '헬스장',
#   '가좌동',
#   '연수동',
#   '구월동',
#   '가좌동',
#   '헬스',
#   '연수동',
#   '헬스',
#   '구월동',
#   '헬스',
#   '젝',
#   '믹스',
#   '샵',
#   '필라테스',
#   '프사',
#   '즐거움',
#   '다이어트',
#   '홈',
#   '트레이닝',
#   '코로나',
#   '바디',
#   '프로필',
#   '헬스'],
#  ['터닝',
#   '포인트',
#   '짐',
#   '연수',
#   '횐님',
#   '프레',
#   '젠또',
#   '오시',
#   '빵',
#   '보따리',
#   '수고',
#   '닷',
#   '횐님',
#   '항상',
#   '횐님들',
#   '관심',
#   '사랑',
#   '연수',
#   '직원',
#   '항상',
#   '불끈불끈',
#   '덕분',
#   '마음',
#   '자세',
#   '하루',
#   '헬스',
#   '골프',
#   '기구',
#   '필라테스',
#   '요가',
#   '스피닝',
#   '댄스',
#   '좌',
#   '연수',
#   '구월',
#   '예술회관역',
#   '터닝',
#   '포인트',
#   '짐',
#   '터닝',
#   '포인트',
#   '짐',
#   '좌점',
#   '터닝',
#   '포인트',
#   '짐',
#   '연수',
#   '터닝',
#   '포인트',
#   '짐',
#   '구월',
#   '터닝',
#   '포인트',
#   '짐',
#   '구월',
#   '예술회관역',
#   '가좌동',
#   '헬스장',
#   '연수동',
#   '헬스장',
#   '구월동',
#   '헬스장',
#   '가좌동',
#   '연수동',
#   '구월동',
#   '가좌동',
#   '헬스',
#   '연수동',
#   '헬스',
#   '구월동',
#   '헬스',
#   '젝',
#   '믹스',
#   '샵',
#   '필라테스',
#   '프사',
#   '즐거움',
#   '다이어트',
#   '홈',
#   '트레이닝',
#   '코로나',
#   '바디',
#   '프로필',
#   '헬스'],
#  ['코로나',
#   '가해진',
#   '저녁',
#   '난',
#   '사브',
#   '작',
#   '사브',
#   '작',
#   '분양',
#   '조명등',
#   '인형',
#   '아크릴',
#   '볼',
#   '공예',
#   '코로나'],
#  ['성남', '분당', '질', '뜨개질', '취미', '가방', '코로나', '극복', '가방'],
#  ['박나리',
#   '근황',
#   '딸기',
#   '드뎌',
#   '딸기',
# ...
#   '개인',
#   '방역',
#   '정부',
#   '방역',
#   '칙',
#   '준수',
#   '터닝',
#   '포인트',
#   '짐',
#   '출입',
#   '시스템',
#   '직원',
#   '코로나',
#   '검사',
#   '실시',
#   '환기',
#   '소독',
#   '매일',
#   '수회',
#   '시행',
#   '방역',
#   '코로나',
#   '센터',
#   '노력',
#   '화이팅',
#   '터닝',
#   '포인트',
#   '짐',
#   '코로나',
#   '코로나',
#   '코로나',
#   '코로나',
#   '이기자',
#   '운동',
#   '스타',
#   '헬',
#   '스타',
#   '필라테스',
#   '다이어트',
#   '운동',
#   '남자',
#   '헬스장',
#   '헬스',
#   '운동',
#   '기구',
#   '필라테스',
#   '요가'],
#  ['린지', '간대협', '간호', '대학', '학생', '협회', '코로나', '극복', '간호사', '간호학'],
#  ['코로나',
#   '파산',
#   '위기',
#   '화성',
#   '급',
#   '공업',
#   '클럽',
#   '튠',
#   '스텀',
#   '페인',
#   '팅',
#   '바디',
#   '킷',
#   '전문',
#   '업체',
#   '수입',
#   '차사',
#   '수리',
#   '일반',
#   '수리',
#   '보험',
#   '수리',
#   '차종',
#   '바디',
#   '킷',
#   '에어',
#   '댐',
#   '도장',
#   '장착',
#   '전체',
#   '도장',
#   '부분',
#   '도장',
#   '포인트',
#   '도장',
#   '특수',
#   '도장',
#   '플레이',
#   '카멜레온',
#   '캔디',
#   '무광',
#   '수리',
#   '보수',
#   '오버',
#   '휀다',
#   '체결',
#   '일체',
#   '구조',
#   '변경',
#   '단기',
#   '장기',
#   '렌트카',
#   '자동차',
#   '관련',
#   '모든',
#   '클럽',
#   '튠',
#   '클럽',
#   '튠',
#   '주소',
#   '경기도',
#   '화성시',
#   '봉담읍',
#   '효',
#   '행로',
#   '튜닝',
#   '바디',
#   '킷',
#   '튜닝카',
#   '슈퍼카',
#   '특수',
#   '도색',
#   '슈퍼카',
#   '자동차',
#   '카',
#   '스타',
#   '플레이',
#   '스타',
#   '오버',
#   '휀다',
#   '에어',
#   '댐',
#   '구조',
#   '변경',
#   '보험',
#   '수리',
#   '사고',
#   '수리',
#   '일반',
#   '수리',
#   '자차',
#   '수리',
#   '클럽',
#   '튠',
#   '안산',
#   '안산',
#   '튜닝',
#   '수원',
#   '튜닝',
#   '시흥',
#   '튜닝',
#   '광명',
#   '튜닝',
#   '슈퍼카',
#   '보수',
#   '급',
#   '공업',
#   '공업',
#   '렌트카',
#   '인스타'],
#  ['실내', '마스크', '코로나'],
#  ['코로나', '코로나', '기록'],
#  ['집콕',
#   '커피',
#   '린지',
#   '위로',
#   '커피',
#   '집콕',
#   '커피',
#   '린지',
#   '지목',
#   '시기',
#   '뜻',
#   '커피',
#   '한잔',
#   '노력',
#   '위로',
#   '의료',
#   '응원',
#   '집콕',
#   '커피',
#   '인증',
#   '선',
#   '의료',
#   '잔',
#   '커피',
#   '집콕',
#   '커피',
#   '생활',
#   '인스타',
#   '포스팅',
#   '영상',
#   '집콕',
#   '커피',
#   '린지',
#   '해시태그',
#   '해시태그',
#   '갯수',
#   '만큼',
#   '커피',
#   '브랜드',
#   '코로나',
#   '전담',
#   '병원',
#   '선',
#   '진료',
#   '커피',
#   '기부',
#   '참여',
#   '독려',
#   '태그',
#   '아지트',
#   '음악',
#   '커피',
#   '공존',
#   '비엔나',
#   '라떼',
#   '역시',
#   '아몬드',
#   '민초',
#   '라떼',
#   '제빵',
#   '선배',
#   '항상',
#   '인생',
#   '선배',
#   '센스',
#   '커피',
#   '책',
#   '취향',
#   '다람쥐',
#   '랜',
#   '커피',
#   '랜',
#   '커피',
#   '브랜드',
#   '커피',
#   '로스',
#   '터스',
#   '커피',
#   '로스',
#   '터스',
#   '나무',
#   '사이',
#   '딥',
#   '블루',
#   '레이크',
#   '멘토',
#   '브루어스',
#   '모모스',
#   '벙커',
#   '컴퍼니',
#   '베르크',
#   '빈',
#   '브라더스',
#   '밋',
#   '컬처',
#   '센터',
#   '커피',
#   '아비시니아',
#   '애',
#   '매틱',
#   '어나더',
#   '룸',
#   '엘',
#   '카페',
#   '카',
#   '플라쥬',
#   '커피',
#   '리브',
#   '레',
#   '커피',
#   '몽타주',
#   '커피',
#   '템플',
#   '파스텔',
#   '커피',
#   '웍스',
#   '펠트',
#   '포비',
#   '프',
#   '린츠',
#   '한국',
#   '커피',
#   '부처',
#   '서울',
#   '적십자',
#   '병원'],
#  ['코로나',
#   '해외여행',
#   '씨',
#   '드',
#   '쉐프',
#   '요',
#   '매달',
#   '여행지',
#   '메',
#   '무',
#   '비트',
#   '립',
#   '기획전',
#   '여행',
#   '뉴욕',
#   '관광',
#   '마케팅',
#   '뉴욕'],
#  ['분명',
#   '휘핑',
#   '코로나',
#   '집',
#   '도착',
#   '나름',
#   '터',
#   '달달',
#   '커피',
#   '속',
#   '속',
#   '난',
#   '성격',
#   '누굴',
#   '천하태평',
#   '스타벅스',
#   '돌체',
#   '콜드',
#   '브루',
#   '휘핑올려',
#   '달달',
#   '스트레스',
#   '스트레스',
#   '해소',
#   '육아',
#   '행복',
#   '행복',
#   '확행',
#   '코로나',
#   '성격',
#   '애',
#   '속'],
#  ['규태',
#   '곱창',
#   '웨이',
#   '팅',
#   '기본',
#   '기본',
#   '맛',
#   '진짜',
#   '말',
#   '잔소리',
#   '웨이',
#   '팅',
#   '구조',
#   '정말',
#   '불구',
#   '정도',
#   '이모',
#   '제일',
#   '정도',
#   '늘',
#   '곱창',
#   '듬',
#   '곱창전골',
#   '꼭',
#   '곱창',
#   '냄새',
#   '곱창',
#   '전혀',
#   '전혀',
#   '비리',
#   '말',
#   '이모',
#   '신경',
#   '곤',
#   '두서',
#   '도약',
#   '두번째',
#   '기분',
#   '밥',
#   '순',
#   '때로는',
#   '자리',
#   '웨이',
#   '팅',
#   '감수',
#   '맛집',
#   '해',
#   '이모',
#   '기분',
#   '악의',
#   '절대',
#   '습',
#   '규태',
#   '곱창',
#   '노',
#   '맛집',
#   '공항',
#   '근처',
#   '제주',
#   '맛집',
#   '제주',
#   '카페',
#   '핫',
#   '코로나'],
#  ['정말',
#   '시국',
#   '바깥',
#   '외출',
#   '조이',
#   '풀',
#   '루시',
#   '신생아',
#   '마스크',
#   '사랑',
#   '점점',
#   '지고',
#   '아기',
#   '마스크',
#   '코로나',
#   '외출',
#   '디자인',
#   '프로필',
#   '링크',
#   '확인',
#   '프로필',
#   '링크',
#   '클릭',
#   '사이트',
#   '이동',
#   '외출',
#   '코로나',
#   '조심',
#   '마음',
#   '외출',
#   '하자',
#   '병원',
#   '뚝',
#   '육아용품',
#   '귀',
#   '마스크',
#   '엄마',
#   '마스크',
#   '아기',
#   '안심',
#   '외출',
#   '마스크',
#   '스트레스'],
#  ['슬기',
#   '럽',
#   '스타',
#   '커플',
#   '커플스',
#   '사회',
#   '코로나',
#   '심드렁',
#   '힘드렁',
#   '까치',
#   '집',
#   '잠옷',
#   '잠옷',
#   '스타'],
#  ['코로나',
#   '실시간',
#   '현황',
#   '코로나',
#   '확산',
#   '세',
#   '한결',
#   '누',
#   '신규',
#   '명대',
#   '중반',
#   '지난',
#   '이후',
#   '사흘',
#   '명대',
#   '개인',
#   '방역',
#   '정부',
#   '방역',
#   '칙',
#   '준수',
#   '터닝',
#   '포인트',
#   '짐',
#   '출입',
#   '시스템',
#   '직원',
#   '코로나',
#   '검사',
#   '실시',
#   '환기',
#   '소독',
#   '매일',
#   '수회',
#   '시행',
#   '방역',
#   '코로나',
#   '센터',
#   '노력',
#   '화이팅',
#   '터닝',
#   '포인트',
#   '짐',
#   '코로나',
#   '코로나',
#   '코로나',
#   '코로나',
#   '이기자',
#   '운동',
#   '스타',
#   '헬',
#   '스타',
#   '필라테스',
#   '다이어트',
#   '운동',
#   '남자',
#   '헬스장',
#   '헬스',
#   '운동',
#   '기구',
#   '필라테스',
#   '요가'],
#  ['코로나',
#   '실시간',
#   '현황',
#   '코로나',
#   '확산',
#   '세',
#   '한결',
#   '누',
#   '신규',
#   '명대',
#   '중반',
#   '지난',
#   '이후',
#   '사흘',
#   '명대',
#   '개인',
#   '방역',
#   '정부',
#   '방역',
#   '칙',
#   '준수',
#   '터닝',
#   '포인트',
#   '짐',
#   '출입',
#   '시스템',
#   '직원',
#   '코로나',
#   '검사',
#   '실시',
#   '환기',
#   '소독',
#   '매일',
#   '수회',
#   '시행',
#   '방역',
#   '코로나',
#   '센터',
#   '노력',
#   '화이팅',
#   '터닝',
#   '포인트',
#   '짐',
#   '코로나',
#   '코로나',
#   '코로나',
#   '코로나',
#   '이기자',
#   '운동',
#   '스타',
#   '헬',
#   '스타',
#   '필라테스',
#   '다이어트',
#   '운동',
#   '남자',
#   '헬스장',
#   '헬스',
#   '운동',
#   '기구',
#   '필라테스',
#   '요가'],
#  ['코로나',
#   '실시간',
#   '현황',
#   '코로나',
#   '확산',
#   '세',
#   '한결',
#   '누',
#   '신규',
#   '명대',
#   '중반',
#   '지난',
#   '이후',
#   '사흘',
#   '명대',
#   '개인',
#   '방역',
#   '정부',
#   '방역',
#   '칙',
#   '준수',
#   '터닝',
#   '포인트',
#   '짐',
#   '출입',
#   '시스템',
#   '직원',
#   '코로나',
#   '검사',
#   '실시',
#   '환기',
#   '소독',
#   '매일',
#   '수회',
#   '시행',
#   '방역',
#   '코로나',
#   '센터',
#   '노력',
#   '화이팅',
#   '터닝',
#   '포인트',
#   '짐',
#   '코로나',
#   '코로나',
#   '코로나',
#   '코로나',
#   '이기자',
#   '운동',
#   '스타',
#   '헬',
#   '스타',
#   '필라테스',
#   '다이어트',
#   '운동',
#   '남자',
#   '헬스장',
#   '헬스',
#   '운동',
#   '기구',
#   '필라테스',
#   '요가'],
#  ['코로나',
#   '전선',
#   '활약',
#   '간호사',
#   '선배',
#   '응원',
#   '린지',
#   '간대협',
#   '간호',
#   '대학생',
#   '협회',
#   '코로나',
#   '극복',
#   '간호사',
#   '간호학',
#   '간호',
#   '학생'],
#  ['문화',
#   '코',
#   '시국',
#   '도서',
#   '윤',
#   '여수',
#   '에세이',
#   '코로나',
#   '시대',
#   '볼',
#   '편의',
#   '영화',
#   '교보',
#   '문고',
#   '예스',
#   '인터파크',
#   '도서',
#   '알라딘',
#   '오프라인',
#   '교보',
#   '문고',
#   '참고',
#   '코',
#   '시국',
#   '코로나',
#   '활동',
#   '중단',
#   '역설',
#   '책',
#   '상황',
#   '코',
#   '시국',
#   '상황',
#   '책',
#   '통해',
#   '마음',
#   '양식',
#   '요',
#   '매달',
#   '마지막',
#   '수요일',
#   '문화',
#   '전국',
#   '도서관',
#   '서점',
#   '책',
#   '마련',
#   '내용',
#   '문화',
#   '블로그',
#   '확인',
#   '프로필',
#   '링크',
#   '문화',
#   '매달',
#   '마지막',
#   '수요일',
#   '코',
#   '시국',
#   '코로나',
#   '독서',
#   '생활',
#   '책',
#   '포스트',
#   '코로나',
#   '대의',
#   '생활',
#   '예술',
#   '방구',
#   '미술관',
#   '코로나',
#   '시대',
#   '집콕',
#   '방법',
#   '코로나',
#   '팬더믹',
#   '난',
#   '인문학',
#   '문화',
#   '체육관',
#   '광부',
#   '지역',
#   '문화',
#   '진흥'],
#  ['컬',
#   '초롱초롱',
#   '눈매',
#   '눈매',
#   '시술',
#   '마스카라',
#   '아침',
#   '화장',
#   '단축',
#   '눈매',
#   '컬',
#   '속눈썹',
#   '샴푸',
#   '속눈썹',
#   '클리',
#   '닉',
#   '베드',
#   '핀셋',
#   '소독',
#   '시술',
#   '안전',
#   '캡',
#   '개인',
#   '변심',
#   '진행중',
#   '첫',
#   '방문',
#   '할인',
#   '쉬',
#   '중',
#   '선택',
#   '제이',
#   '앤컬',
#   '검색'],
#  ['코로나',
#   '실시간',
#   '현황',
#   '코로나',
#   '확산',
#   '세',
#   '한결',
#   '누',
#   '신규',
#   '명대',
#   '중반',
#   '지난',
#   '이후',
#   '사흘',
#   '명대',
#   '개인',
#   '방역',
#   '정부',
#   '방역',
#   '칙',
#   '준수',
#   '터닝',
#   '포인트',
#   '짐',
#   '출입',
#   '시스템',
#   '직원',
#   '코로나',
#   '검사',
#   '실시',
#   '환기',
#   '소독',
#   '매일',
#   '수회',
#   '시행',
#   '방역',
#   '코로나',
#   '센터',
#   '노력',
#   '화이팅',
#   '터닝',
#   '포인트',
#   '짐',
#   '코로나',
#   '코로나',
#   '코로나',
#   '코로나',
#   '이기자',
#   '운동',
#   '스타',
#   '헬',
#   '스타',
#   '필라테스',
#   '다이어트',
#   '운동',
#   '남자',
#   '헬스장',
#   '헬스',
#   '운동',
#   '기구',
#   '필라테스',
#   '요가'],
#  ['헬스장',
#   '납품',
#   '수량',
#   '독',
#   '차로',
#   '가온',
#   '가온',
#   '휘트니',
#   '스',
#   '좌',
#   '싸이클',
#   '좌',
#   '자전거',
#   '입',
#   '싸이클',
#   '입',
#   '자전거',
#   '운동',
#   '운동',
#   '기구',
#   '헬스',
#   '헬스',
#   '기구',
#   '웨이',
#   '트',
#   '하체',
#   '기구',
#   '하체',
#   '운동',
#   '다이어트',
#   '가정',
#   '용',
#   '자전거',
#   '가정',
#   '용운동',
#   '기구',
#   '코로나',
#   '운동',
#   '코로나',
#   '홈',
#   '트레이닝',
#   '홈트',
#   '스텝'],
#  ['산책',
#   '산책',
#   '바퀴',
#   '공원',
#   '걷기',
#   '운동',
#   '안개',
#   '카메라',
#   '뒷모습',
#   '인스타',
#   '공유',
#   '금요일',
#   '코로나',
#   '훠이훠이'],
#  ['코로나',
#   '실시간',
#   '현황',
#   '코로나',
#   '확산',
#   '세',
#   '한결',
#   '누',
#   '신규',
#   '명대',
#   '중반',
#   '지난',
#   '이후',
#   '사흘',
#   '명대',
#   '개인',
#   '방역',
#   '정부',
#   '방역',
#   '칙',
#   '준수',
#   '터닝',
#   '포인트',
#   '짐',
#   '출입',
#   '시스템',
#   '직원',
#   '코로나',
#   '검사',
#   '실시',
#   '환기',
#   '소독',
#   '매일',
#   '수회',
#   '시행',
#   '방역',
#   '코로나',
#   '센터',
#   '노력',
#   '화이팅',
#   '터닝',
#   '포인트',
#   '짐',
#   '코로나',
#   '코로나',
#   '코로나',
#   '코로나',
#   '이기자',
#   '운동',
#   '스타',
#   '헬',
#   '스타',
#   '필라테스',
#   '다이어트',
#   '운동',
#   '남자',
#   '헬스장',
#   '헬스',
#   '운동',
#   '기구',
#   '필라테스',
#   '요가'],
#  ['코로나', '검사', '뇌', '콧물', '코로나'],
#  ['코로나',
#   '실시간',
#   '현황',
#   '코로나',
#   '확산',
#   '세',
#   '한결',
#   '누',
#   '신규',
#   '명대',
#   '중반',
#   '지난',
#   '이후',
#   '사흘',
#   '명대',
#   '개인',
#   '방역',
#   '정부',
#   '방역',
#   '칙',
#   '준수',
#   '터닝',
#   '포인트',
#   '짐',
#   '출입',
#   '시스템',
#   '직원',
#   '코로나',
#   '검사',
#   '실시',
#   '환기',
#   '소독',
#   '매일',
#   '수회',
#   '시행',
#   '방역',
#   '코로나',
#   '센터',
#   '노력',
#   '화이팅',
#   '터닝',
#   '포인트',
#   '짐',
#   '코로나',
#   '코로나',
#   '코로나',
#   '코로나',
#   '이기자',
#   '운동',
#   '스타',
#   '헬',
#   '스타',
#   '필라테스',
#   '다이어트',
#   '운동',
#   '남자',
#   '헬스장',
#   '헬스',
#   '운동',
#   '기구',
#   '필라테스',
#   '요가'],
#  ['햇님',
#   '플레이',
#   '위',
#   '위',
#   '쇼핑',
#   '안스',
#   '밖',
#   '놀',
#   '순',
#   '실내',
#   '에너지',
#   '발산',
#   '위',
#   '햇님',
#   '토이',
#   '놀이기구',
#   '상품',
#   '구경',
#   '상단',
#   '프로필',
#   '주소',
#   '클릭',
#   '햇님',
#   '토이',
#   '코로나',
#   '극복',
#   '장난감',
#   '키카',
#   '놀이',
#   '방',
#   '인테리어',
#   '도치',
#   '육아',
#   '템',
#   '육아',
#   '필수',
#   '템',
#   '아스타',
#   '이벤트',
#   '할인',
#   '행사'],
#  ['수작', '부리', '일주일', '한번', '등원', '그림'],
#  ['장', '장', '찌'],
#  ['운동', '가방', '필수', '가방', '작', '수납', '공간', '스트로', '스', '가방'],
#  ['학원',
#   '인생',
#   '년생',
#   '전주',
#   '고딩',
#   '미용',
#   '미용',
#   '학원',
#   '미용',
#   '실기',
#   '필기',
#   '마스크',
#   '코로나'],
#  ['부스스',
#   '머리',
#   '앞머리',
#   '난리',
#   '금요일',
#   '내일',
#   '주말',
#   '직장인',
#   '직장',
#   '얼빡샷',
#   '스타',
#   '스타',
#   '휴식',
#   '충전',
#   '화장',
#   '진해',
#   '일주일',
#   '수고',
#   '하자',
#   '화이팅',
#   '커피',
#   '필수',
#   '코로나',
#   '코로나',
#   '마스크',
#   '주말',
#   '코로나',
#   '조심'],
#  ['작년', '코로나', '뮤지컬', '예술의전당', '웃는남자'],
#  ['코로나',
#   '실시간',
#   '현황',
#   '코로나',
#   '확산',
#   '세',
#   '한결',
#   '누',
#   '신규',
#   '명대',
#   '중반',
#   '지난',
#   '이후',
#   '사흘',
#   '명대',
#   '개인',
#   '방역',
#   '정부',
#   '방역',
#   '칙',
#   '준수',
#   '터닝',
#   '포인트',
#   '짐',
#   '출입',
#   '시스템',
#   '직원',
#   '코로나',
#   '검사',
#   '실시',
#   '환기',
#   '소독',
#   '매일',
#   '수회',
#   '시행',
#   '방역',
#   '코로나',
#   '센터',
#   '노력',
#   '화이팅',
#   '터닝',
#   '포인트',
#   '짐',
#   '코로나',
#   '코로나',
#   '코로나',
#   '코로나',
#   '이기자',
#   '운동',
#   '스타',
#   '헬',
#   '스타',
#   '필라테스',
#   '다이어트',
#   '운동',
#   '남자',
#   '헬스장',
#   '헬스',
#   '운동',
#   '기구',
#   '필라테스',
#   '요가'],
#  ['코로나',
#   '전선',
#   '간호사',
#   '선생님',
#   '항상',
#   '응원',
#   '린지',
#   '간대협',
#   '간호',
#   '대학',
#   '학생',
#   '협회',
#   '코로나',
#   '극복',
#   '간호사',
#   '간호학'],
#  ['코로나',
#   '실시간',
#   '현황',
#   '코로나',
#   '확산',
#   '세',
#   '한결',
#   '누',
#   '신규',
#   '명대',
#   '중반',
#   '지난',
#   '이후',
#   '사흘',
#   '명대',
#   '개인',
#   '방역',
#   '정부',
#   '방역',
#   '칙',
#   '준수',
#   '터닝',
#   '포인트',
#   '짐',
#   '출입',
#   '시스템',
#   '직원',
#   '코로나',
#   '검사',
#   '실시',
#   '환기',
#   '소독',
#   '매일',
#   '수회',
#   '시행',
#   '방역',
#   '코로나',
#   '센터',
#   '노력',
#   '화이팅',
#   '터닝',
#   '포인트',
#   '짐',
#   '코로나',
#   '코로나',
#   '코로나',
#   '코로나',
#   '이기자',
#   '운동',
#   '스타',
#   '헬',
#   '스타',
#   '필라테스',
#   '다이어트',
#   '운동',
#   '남자',
#   '헬스장',
#   '헬스',
#   '운동',
#   '기구',
#   '필라테스',
#   '요가'],
#  ['딸램',
#   '보',
#   '걷기',
#   '올리브영',
#   '팩',
#   '여드름',
#   '딸',
#   '위',
#   '팩',
#   '코로나',
#   '다이어트',
#   '보',
#   '걷기',
#   '올리브영',
#   '팩',
#   '팩',
#   '여드름',
#   '고민',
#   '여드름',
#   '팩'],
#  ['코로나',
#   '실시간',
#   '현황',
#   '코로나',
#   '확산',
#   '세',
#   '한결',
#   '누',
#   '신규',
#   '명대',
#   '중반',
#   '지난',
#   '이후',
#   '사흘',
#   '명대',
#   '개인',
#   '방역',
#   '정부',
#   '방역',
#   '칙',
#   '준수',
#   '터닝',
#   '포인트',
#   '짐',
#   '출입',
#   '시스템',
#   '직원',
#   '코로나',
#   '검사',
#   '실시',
#   '환기',
#   '소독',
#   '매일',
#   '수회',
#   '시행',
#   '방역',
#   '코로나',
#   '센터',
#   '노력',
#   '화이팅',
#   '터닝',
#   '포인트',
#   '짐',
#   '코로나',
#   '코로나',
#   '코로나',
#   '코로나',
#   '이기자',
#   '운동',
#   '스타',
#   '헬',
#   '스타',
#   '필라테스',
#   '다이어트',
#   '운동',
#   '남자',
#   '헬스장',
#   '헬스',
#   '운동',
#   '기구',
#   '필라테스',
#   '요가'],
#  ['르몽',
#   '율',
#   '밍퍼',
#   '탑',
#   '다음주',
#   '월요일',
#   '업데이트',
#   '예정',
#   '선',
#   '할인',
#   '가격',
#   '다이렉트',
#   '카톡'],
#  ['아아',
#   '인스타',
#   '스타',
#   '스타',
#   '문화생활',
#   '커피',
#   '카페',
#   '볼링',
#   '볼링',
#   '스타',
#   '술',
#   '스타',
#   '수지구',
#   '인계동',
#   '상현동',
#   '동천동',
#   '코로나',
#   '파마',
#   '동탄',
#   '석우',
#   '관리자',
#   '코로나'],
#  ['노랑', '겨울', '하늘', '학교', '코로나', '마스크', '햇빚'],
#  ['코로나',
#   '웹캠',
#   '대량',
#   '비대',
#   '면접',
#   '온라인수업',
#   '이마트',
#   '광산',
#   '층',
#   '가전',
#   '매장',
#   '어서',
#   '이마트',
#   '광산',
#   '플루',
#   '상품',
#   '웹캠',
#   '카메라',
#   '코로나',
#   '온라인수업',
#   '면접',
#   '행사',
#   '광수',
#   '과일',
#   '한우',
#   '생활',
#   '수산',
#   '화장품',
#   '피자',
#   '치킨',
#   '스타',
#   '맛스타',
#   '행사',
#   '상품'],
#  ['눈', '용', '한번'],
#  ['국민',
#   '헌혈',
#   '참여',
#   '지속',
#   '개인',
#   '단체',
#   '헌혈',
#   '증대',
#   '총력',
#   '혈액',
#   '수급',
#   '어려움',
#   '상황',
#   '처',
#   '환자',
#   '생명',
#   '헌혈',
#   '동참',
#   '헌혈',
#   '현장',
#   '방문',
#   '마스크',
#   '꼭',
#   '착용',
#   '헌혈',
#   '카페',
#   '헌혈',
#   '버스',
#   '한마음혈액원'],
#  ['집', '최대한', '사람', '확인', '아쿠아리움', '해운대', '씨', '라이프', '아쿠아리움', '제발', '코로나'],
#  ['협찬',
#   '바프',
#   '몸',
#   '생리',
#   '주기',
#   '제일',
#   '원래',
#   '상태',
#   '집중',
#   '요하',
#   '탄수화물',
#   '섭취',
#   '체내',
#   '체지방',
#   '잉여',
#   '롭',
#   '맥스',
#   '컷',
#   '도움',
#   '양제',
#   '보조',
#   '운동',
#   '헬스',
#   '헬퍼',
#   '맥스',
#   '컷',
#   '휴대',
#   '간편',
#   '다이어트',
#   '밥',
#   '알',
#   '다이어트',
#   '탄수화물',
#   '컷팅제',
#   '치팅',
#   '필수',
#   '템',
#   '헬린',
#   '눈',
#   '바디',
#   '홈트',
#   '코로나',
#   '스타',
#   '운동',
#   '요가',
#   '강사',
#   '필라테스',
#   '강사',
#   '다이어트'],
#  ['아무',
#   '말',
#   '즉흥',
#   '여행',
#   '가야',
#   '번쩍',
#   '코로나',
#   '때매',
#   '발',
#   '서울',
#   '대전',
#   '대구',
#   '부산',
#   '제주도',
#   '여행',
#   '바다',
#   '여행',
#   '여행',
#   '스타',
#   '코로나',
#   '집콕'],
#  ['세이',
#   '프라임',
#   '세이',
#   '프라임',
#   '화상',
#   '카메라',
#   '뿐',
#   '호흡',
#   '플라즈마',
#   '공기',
#   '살균',
#   '기',
#   '플라즈마',
#   '살균',
#   '소독기',
#   '세균',
#   '박테리아',
#   '바이러스',
#   '국민',
#   '적',
#   '코로나',
#   '바이러스',
#   '사멸',
#   '내용',
#   '아래',
#   '홈페이지',
#   '확인'],
#  ['코로나',
#   '실시간',
#   '현황',
#   '코로나',
#   '확산',
#   '세',
#   '한결',
#   '누',
#   '신규',
#   '명대',
#   '중반',
#   '지난',
#   '이후',
#   '사흘',
#   '명대',
#   '개인',
#   '방역',
#   '정부',
#   '방역',
#   '칙',
#   '준수',
#   '터닝',
#   '포인트',
#   '짐',
#   '출입',
#   '시스템',
#   '직원',
#   '코로나',
#   '검사',
#   '실시',
#   '환기',
#   '소독',
#   '매일',
#   '수회',
#   '시행',
#   '방역',
#   '코로나',
#   '센터',
#   '노력',
#   '화이팅',
#   '터닝',
#   '포인트',
#   '짐',
#   '코로나',
#   '코로나',
#   '코로나',
#   '코로나',
#   '이기자',
#   '운동',
#   '스타',
#   '헬',
#   '스타',
#   '필라테스',
#   '다이어트',
#   '운동',
#   '남자',
#   '헬스장',
#   '헬스',
#   '운동',
#   '기구',
#   '필라테스',
#   '요가'],
#  ['벌',
#   '기본',
#   '책임감',
#   '답장',
#   '실제',
#   '수익',
#   '인증',
#   '자료',
#   '덕분',
#   '항상',
#   '사랑',
#   '카톡',
#   '대구',
#   '집밥',
#   '밥',
#   '순이',
#   '집밥',
#   '스타',
#   '요리',
#   '엄마',
#   '요리',
#   '홈쿡',
#   '집콕',
#   '코로나',
#   '집',
#   '맛집',
#   '요리',
#   '거',
#   '테',
#   '댓',
#   '유칼립투스',
#   '유',
#   '칼립'],
#  ['코로나',
#   '실시간',
#   '현황',
#   '코로나',
#   '확산',
#   '세',
#   '한결',
#   '누',
#   '신규',
#   '명대',
#   '중반',
#   '지난',
#   '이후',
#   '사흘',
#   '명대',
#   '개인',
#   '방역',
#   '정부',
#   '방역',
#   '칙',
#   '준수',
#   '터닝',
#   '포인트',
#   '짐',
#   '출입',
#   '시스템',
#   '직원',
#   '코로나',
#   '검사',
#   '실시',
#   '환기',
#   '소독',
#   '매일',
#   '수회',
#   '시행',
#   '방역',
#   '코로나',
#   '센터',
#   '노력',
#   '화이팅',
#   '터닝',
#   '포인트',
#   '짐',
#   '코로나',
#   '코로나',
#   '코로나',
#   '코로나',
#   '이기자',
#   '운동',
#   '스타',
#   '헬',
#   '스타',
#   '필라테스',
#   '다이어트',
#   '운동',
#   '남자',
#   '헬스장',
#   '헬스',
#   '운동',
#   '기구',
#   '필라테스',
#   '요가'],
#  ['금요일',
#   '유',
#   '칼리',
#   '반함',
#   '반함',
#   '엄마',
#   '대구',
#   '집밥',
#   '밥',
#   '순이',
#   '집밥',
#   '스타',
#   '요리',
#   '엄마',
#   '요리',
#   '홈쿡',
#   '집콕',
#   '코로나',
#   '집',
#   '맛집',
#   '요리',
#   '거',
#   '테',
#   '댓',
#   '유칼립투스',
#   '유',
#   '칼립'],
#  ['인코브',
#   '카니발',
#   '무빙',
#   '랜덤',
#   '도어스',
#   '커프',
#   '문',
#   '동작',
#   '가지',
#   '프로그램',
#   '랜덤',
#   '점등',
#   '디자인',
#   '체감',
#   '사의',
#   '일반',
#   '아크릴',
#   '비교',
#   '불가',
#   '투명',
#   '광',
#   '확산',
#   '소재',
#   '인코브',
#   '도어스',
#   '커프',
#   '어안',
#   '랜즈',
#   '설계',
#   '적용',
#   '빛',
#   '확산',
#   '최대한',
#   '광량',
#   '차종',
#   '적용',
#   '열',
#   '장착',
#   '차량',
#   '작업',
#   '로고',
#   '디자인',
#   '제작',
#   '커스터',
#   '마',
#   '이즈',
#   '장착',
#   '인코브',
#   '품질',
#   '보증',
#   '인코브',
#   '해외',
#   '파트너',
#   '모집',
#   '해외',
#   '지사',
#   '설립',
#   '수출',
#   '유통업체',
#   '모집',
#   '창업',
#   '교육',
#   '인코브',
#   '카니발',
#   '세대',
#   '신형',
#   '카니발',
#   '코로나'],
#  ['코로나',
#   '실시간',
#   '현황',
#   '코로나',
#   '확산',
#   '세',
#   '한결',
#   '누',
#   '신규',
#   '명대',
#   '중반',
#   '지난',
#   '이후',
#   '사흘',
#   '명대',
#   '개인',
#   '방역',
#   '정부',
#   '방역',
#   '칙',
#   '준수',
#   '터닝',
#   '포인트',
#   '짐',
#   '출입',
#   '시스템',
#   '직원',
#   '코로나',
#   '검사',
#   '실시',
#   '환기',
#   '소독',
#   '매일',
#   '수회',
#   '시행',
#   '방역',
#   '코로나',
#   '센터',
#   '노력',
#   '화이팅',
#   '터닝',
#   '포인트',
#   '짐',
#   '코로나',
#   '코로나',
#   '코로나',
#   '코로나',
#   '이기자',
#   '운동',
#   '스타',
#   '헬',
#   '스타',
#   '필라테스',
#   '다이어트',
#   '운동',
#   '남자',
#   '헬스장',
#   '헬스',
#   '운동',
#   '기구',
#   '필라테스',
#   '요가'],
#  ['변경',
#   '정상',
#   '영업',
#   '중',
#   '버킷리스트',
#   '사회',
#   '코로나',
#   '영업',
#   '코로나',
#   '조심',
#   '성신여대',
#   '맛집',
#   '성신여대',
#   '술집',
#   '성신여대',
#   '버킷리스트'],
#  ['벌써',
#   '코로나',
#   '검사',
#   '마스크',
#   '착용',
#   '이행',
#   '률',
#   '코로나',
#   '올해',
#   '꼭',
#   '의료',
#   '덕분',
#   '출처',
#   '질병',
#   '청',
#   '올레',
#   '컬',
#   '홈페이지',
#   '컬',
#   '블로그',
#   '컬',
#   '컬',
#   '티비',
#   '건강',
#   '의료',
#   '건강',
#   '방송',
#   '의료',
#   '방송',
#   '코로나',
#   '코로나',
#   '코로나',
#   '극복'],
#  ['코로나',
#   '막막',
#   '쿠키',
#   '코로나',
#   '육아',
#   '쿠키',
#   '쿠키',
#   '키트',
#   '아들',
#   '파마',
#   '아들',
#   '스타',
#   '육아',
#   '육아']]

# %%
te = TransactionEncoder()
dataset = te.fit(transactions).transform(transactions)
df = pd.DataFrame(data=dataset, columns=te.columns_)
df
# Out:
#         가게     가격     가계     가공     가구     가기    가까이     가끔     가나     가내  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 994  False  False  False  False  False  False  False  False  False  False
# 995  False  False  False  False  False  False  False  False  False  False
# 996  False  False  False  False  False  False  False  False  False  False
# 997  False  False  False  False  False  False  False  False  False  False
# 998  False  False  False  False  False  False  False  False  False  False
#
#      ...     희생     흰소    히나타     히든  히알루론산     히터    힐러리    힘드렁     힙업      힝
# 0    ...  False  False  False  False  False  False  False  False  False  False
# 1    ...  False  False  False  False  False  False  False  False  False  False
# 2    ...  False  False  False  False  False  False  False  False  False  False
# 3    ...  False  False  False  False  False  False  False  False  False  False
# 4    ...  False  False  False  False  False  False  False  False  False  False
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 994  ...  False  False  False  False  False  False  False  False  False  False
# 995  ...  False  False  False  False  False  False  False  False  False  False
# 996  ...  False  False  False  False  False  False  False  False  False  False
# 997  ...  False  False  False  False  False  False  False  False  False  False
# 998  ...  False  False  False  False  False  False  False  False  False  False
#
# [999 rows x 6147 columns]
